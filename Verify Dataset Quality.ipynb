# %% [markdown]
# # **1. File Integrity**
# •	  No corrupted or unreadable image files.
#
#
# •	  All images open correctly and are in supported formats (.jpg, .png, etc.).

# %%
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
from PIL import Image

def check_image_status(directory):
    if not os.path.isdir(directory):
        print(f"Error: Directory not found at {directory}")
        return

    print(f"Checking images in directory: {directory}")
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)
        if os.path.isfile(filepath):
            try:
                img = Image.open(filepath)
                img.verify()  # Verify that the file is an image
                print(f"{filename}: NOT corrupted")
            except (IOError, SyntaxError) as e:
                print(f"{filename}: IS corrupted - {e}")
            except Exception as e:
                print(f"{filename}: Could not process - {e}")
        else:
            print(f"{filename}: IS NOT a file (skipping)")

# %%
address='/content/drive/My Drive/PROJECT1/data/data_set(15,15,70)'
class_es=['test','train','valid']
sub_class_es=['Immature','Mature','Normal']

# %%
for cls in class_es:
  for sub_cls in sub_class_es:
    print(address+'/'+cls+'/'+sub_cls)
    check_image_status(address+'/'+cls+'/'+sub_cls)
# Out:
# Streaming output truncated to the last 5000 lines.
# Immature (492).jpg: NOT corrupted
# Immature (493).jpg: NOT corrupted
# Immature (494).jpg: NOT corrupted
# Immature (495).jpg: NOT corrupted
# Immature (496).jpg: NOT corrupted
# Immature (497).jpg: NOT corrupted
# Immature (498).jpg: NOT corrupted
# Immature (499).jpg: NOT corrupted
# Immature (500).jpg: NOT corrupted
# Immature (501).jpg: NOT corrupted
# Immature (502).jpg: NOT corrupted
# Immature (503).jpg: NOT corrupted
# Immature (504).jpg: NOT corrupted
# Immature (505).jpg: NOT corrupted
# Immature (506).jpg: NOT corrupted
# Immature (507).jpg: NOT corrupted
# Immature (508).jpg: NOT corrupted
# Immature (509).jpg: NOT corrupted
# Immature (510).jpg: NOT corrupted
# Immature (511).jpg: NOT corrupted
# Immature (512).jpg: NOT corrupted
# Immature (513).jpg: NOT corrupted
# Immature (514).jpg: NOT corrupted
# Immature (515).jpg: NOT corrupted
# Immature (516).jpg: NOT corrupted
# Immature (517).jpg: NOT corrupted
# Immature (518).jpg: NOT corrupted
# Immature (519).jpg: NOT corrupted
# Immature (520).jpg: NOT corrupted
# Immature (521).jpg: NOT corrupted
# Immature (522).jpg: NOT corrupted
# Immature (523).jpg: NOT corrupted
# Immature (524).jpg: NOT corrupted
# Immature (525).jpg: NOT corrupted
# Immature (526).jpg: NOT corrupted
# Immature (527).jpg: NOT corrupted
# Immature (528).jpg: NOT corrupted
# Immature (529).jpg: NOT corrupted
# Immature (530).jpg: NOT corrupted
# Immature (531).jpg: NOT corrupted
# Immature (532).jpg: NOT corrupted
# Immature (533).jpg: NOT corrupted
# Immature (534).jpg: NOT corrupted
# Immature (535).jpg: NOT corrupted
# Immature (536).jpg: NOT corrupted
# Immature (537).jpg: NOT corrupted
# Immature (538).jpg: NOT corrupted
# Immature (539).jpg: NOT corrupted
# Immature (540).jpg: NOT corrupted
# Immature (541).jpg: NOT corrupted
# Immature (542).jpg: NOT corrupted
# Immature (543).jpg: NOT corrupted
# Immature (544).jpg: NOT corrupted
# Immature (545).jpg: NOT corrupted
# Immature (546).jpg: NOT corrupted
# Immature (547).jpg: NOT corrupted
# Immature (548).jpg: NOT corrupted
# Immature (549).jpg: NOT corrupted
# Immature (550).jpg: NOT corrupted
# Immature (551).jpg: NOT corrupted
# Immature (552).jpg: NOT corrupted
# Immature (553).jpg: NOT corrupted
# Immature (554).jpg: NOT corrupted
# Immature (555).jpg: NOT corrupted
# Immature (556).jpg: NOT corrupted
# Immature (557).jpg: NOT corrupted
# Immature (558).jpg: NOT corrupted
# Immature (559).jpg: NOT corrupted
# Immature (560).jpg: NOT corrupted
# Immature (561).jpg: NOT corrupted
# Immature (562).jpg: NOT corrupted
# Immature (563).jpg: NOT corrupted
# Immature (564).jpg: NOT corrupted
# Immature (565).jpg: NOT corrupted
# Immature (566).jpg: NOT corrupted
# Immature (567).jpg: NOT corrupted
# Immature (568).jpg: NOT corrupted
# Immature (569).jpg: NOT corrupted
# Immature (570).jpg: NOT corrupted
# Immature (571).jpg: NOT corrupted
# Immature (572).jpg: NOT corrupted
# Immature (573).jpg: NOT corrupted
# Immature (574).jpg: NOT corrupted
# Immature (575).jpg: NOT corrupted
# Immature (576).jpg: NOT corrupted
# Immature (577).jpg: NOT corrupted
# Immature (578).jpg: NOT corrupted
# Immature (579).jpg: NOT corrupted
# Immature (580).jpg: NOT corrupted
# Immature (581).jpg: NOT corrupted
# Immature (582).jpg: NOT corrupted
# Immature (583).jpg: NOT corrupted
# Immature (584).jpg: NOT corrupted
# Immature (585).jpg: NOT corrupted
# Immature (586).jpg: NOT corrupted
# Immature (587).jpg: NOT corrupted
# Immature (588).jpg: NOT corrupted
# Immature (589).jpg: NOT corrupted
# Immature (590).jpg: NOT corrupted
# Immature (591).jpg: NOT corrupted
# Immature (592).jpg: NOT corrupted
# Immature (593).jpg: NOT corrupted
# Immature (594).jpg: NOT corrupted
# Immature (595).jpg: NOT corrupted
# Immature (596).jpg: NOT corrupted
# Immature (597).jpg: NOT corrupted
# Immature (598).jpg: NOT corrupted
# Immature (599).jpg: NOT corrupted
# Immature (600).jpg: NOT corrupted
# Immature (601).jpg: NOT corrupted
# Immature (602).jpg: NOT corrupted
# Immature (603).jpg: NOT corrupted
# Immature (604).jpg: NOT corrupted
# Immature (605).jpg: NOT corrupted
# Immature (606).jpg: NOT corrupted
# Immature (607).jpg: NOT corrupted
# Immature (608).jpg: NOT corrupted
# Immature (609).jpg: NOT corrupted
# Immature (610).jpg: NOT corrupted
# Immature (611).jpg: NOT corrupted
# Immature (612).jpg: NOT corrupted
# Immature (613).jpg: NOT corrupted
# Immature (614).jpg: NOT corrupted
# Immature (615).jpg: NOT corrupted
# Immature (616).jpg: NOT corrupted
# Immature (617).jpg: NOT corrupted
# Immature (618).jpg: NOT corrupted
# Immature (619).jpg: NOT corrupted
# Immature (620).jpg: NOT corrupted
# Immature (621).jpg: NOT corrupted
# Immature (622).jpg: NOT corrupted
# Immature (623).jpg: NOT corrupted
# Immature (624).jpg: NOT corrupted
# Immature (625).jpg: NOT corrupted
# Immature (626).jpg: NOT corrupted
# Immature (627).jpg: NOT corrupted
# Immature (628).jpg: NOT corrupted
# Immature (629).jpg: NOT corrupted
# Immature (630).jpg: NOT corrupted
# Immature (631).jpg: NOT corrupted
# Immature (632).jpg: NOT corrupted
# Immature (633).jpg: NOT corrupted
# Immature (634).jpg: NOT corrupted
# Immature (635).jpg: NOT corrupted
# Immature (636).jpg: NOT corrupted
# Immature (637).jpg: NOT corrupted
# Immature (638).jpg: NOT corrupted
# Immature (639).jpg: NOT corrupted
# Immature (640).jpg: NOT corrupted
# Immature (641).jpg: NOT corrupted
# Immature (642).jpg: NOT corrupted
# Immature (643).jpg: NOT corrupted
# Immature (644).jpg: NOT corrupted
# Immature (645).jpg: NOT corrupted
# Immature (646).jpg: NOT corrupted
# Immature (647).jpg: NOT corrupted
# Immature (648).jpg: NOT corrupted
# Immature (649).jpg: NOT corrupted
# Immature (650).jpg: NOT corrupted
# Immature (651).jpg: NOT corrupted
# Immature (652).jpg: NOT corrupted
# Immature (653).jpg: NOT corrupted
# Immature (654).jpg: NOT corrupted
# Immature (655).jpg: NOT corrupted
# Immature (656).jpg: NOT corrupted
# Immature (657).jpg: NOT corrupted
# Immature (658).jpg: NOT corrupted
# Immature (659).jpg: NOT corrupted
# Immature (660).jpg: NOT corrupted
# Immature (661).jpg: NOT corrupted
# Immature (662).jpg: NOT corrupted
# Immature (663).jpg: NOT corrupted
# Immature (664).jpg: NOT corrupted
# Immature (665).jpg: NOT corrupted
# Immature (666).jpg: NOT corrupted
# Immature (667).jpg: NOT corrupted
# Immature (668).jpg: NOT corrupted
# Immature (669).jpg: NOT corrupted
# Immature (670).jpg: NOT corrupted
# Immature (671).jpg: NOT corrupted
# Immature (672).jpg: NOT corrupted
# Immature (673).jpg: NOT corrupted
# Immature (674).jpg: NOT corrupted
# Immature (675).jpg: NOT corrupted
# Immature (676).jpg: NOT corrupted
# Immature (677).jpg: NOT corrupted
# Immature (678).jpg: NOT corrupted
# Immature (679).jpg: NOT corrupted
# Immature (680).jpg: NOT corrupted
# Immature (681).jpg: NOT corrupted
# Immature (682).jpg: NOT corrupted
# Immature (683).jpg: NOT corrupted
# Immature (684).jpg: NOT corrupted
# Immature (685).jpg: NOT corrupted
# Immature (686).jpg: NOT corrupted
# Immature (687).jpg: NOT corrupted
# Immature (688).jpg: NOT corrupted
# Immature (689).jpg: NOT corrupted
# Immature (690).jpg: NOT corrupted
# Immature (691).jpg: NOT corrupted
# Immature (692).jpg: NOT corrupted
# Immature (693).jpg: NOT corrupted
# Immature (694).jpg: NOT corrupted
# Immature (695).jpg: NOT corrupted
# Immature (696).jpg: NOT corrupted
# Immature (697).jpg: NOT corrupted
# Immature (698).jpg: NOT corrupted
# Immature (699).jpg: NOT corrupted
# Immature (700).jpg: NOT corrupted
# Immature (701).jpg: NOT corrupted
# Immature (702).jpg: NOT corrupted
# Immature (703).jpg: NOT corrupted
# Immature (704).jpg: NOT corrupted
# Immature (705).jpg: NOT corrupted
# Immature (706).jpg: NOT corrupted
# Immature (707).jpg: NOT corrupted
# Immature (708).jpg: NOT corrupted
# Immature (709).jpg: NOT corrupted
# Immature (710).jpg: NOT corrupted
# Immature (711).jpg: NOT corrupted
# Immature (712).jpg: NOT corrupted
# Immature (713).jpg: NOT corrupted
# Immature (714).jpg: NOT corrupted
# Immature (715).jpg: NOT corrupted
# Immature (716).jpg: NOT corrupted
# Immature (717).jpg: NOT corrupted
# Immature (718).jpg: NOT corrupted
# Immature (719).jpg: NOT corrupted
# Immature (720).jpg: NOT corrupted
# Immature (721).jpg: NOT corrupted
# Immature (722).jpg: NOT corrupted
# Immature (723).jpg: NOT corrupted
# Immature (724).jpg: NOT corrupted
# Immature (725).jpg: NOT corrupted
# Immature (726).jpg: NOT corrupted
# Immature (727).jpg: NOT corrupted
# Immature (728).jpg: NOT corrupted
# Immature (729).jpg: NOT corrupted
# Immature (730).jpg: NOT corrupted
# Immature (731).jpg: NOT corrupted
# Immature (732).jpg: NOT corrupted
# Immature (733).jpg: NOT corrupted
# Immature (734).jpg: NOT corrupted
# Immature (735).jpg: NOT corrupted
# Immature (736).jpg: NOT corrupted
# Immature (737).jpg: NOT corrupted
# Immature (738).jpg: NOT corrupted
# Immature (739).jpg: NOT corrupted
# Immature (740).jpg: NOT corrupted
# Immature (741).jpg: NOT corrupted
# Immature (742).jpg: NOT corrupted
# Immature (743).jpg: NOT corrupted
# Immature (744).jpg: NOT corrupted
# Immature (745).jpg: NOT corrupted
# Immature (746).jpg: NOT corrupted
# Immature (747).jpg: NOT corrupted
# Immature (748).jpg: NOT corrupted
# Immature (749).jpg: NOT corrupted
# Immature (750).jpg: NOT corrupted
# Immature (751).jpg: NOT corrupted
# Immature (752).jpg: NOT corrupted
# Immature (753).jpg: NOT corrupted
# Immature (754).jpg: NOT corrupted
# Immature (755).jpg: NOT corrupted
# Immature (756).jpg: NOT corrupted
# Immature (757).jpg: NOT corrupted
# Immature (758).jpg: NOT corrupted
# Immature (759).jpg: NOT corrupted
# Immature (760).jpg: NOT corrupted
# Immature (761).jpg: NOT corrupted
# Immature (762).jpg: NOT corrupted
# Immature (763).jpg: NOT corrupted
# Immature (764).jpg: NOT corrupted
# Immature (765).jpg: NOT corrupted
# Immature (766).jpg: NOT corrupted
# Immature (767).jpg: NOT corrupted
# Immature (768).jpg: NOT corrupted
# Immature (769).jpg: NOT corrupted
# Immature (770).jpg: NOT corrupted
# Immature (771).jpg: NOT corrupted
# Immature (772).jpg: NOT corrupted
# Immature (773).jpg: NOT corrupted
# Immature (774).jpg: NOT corrupted
# Immature (775).jpg: NOT corrupted
# Immature (776).jpg: NOT corrupted
# Immature (777).jpg: NOT corrupted
# Immature (778).jpg: NOT corrupted
# Immature (779).jpg: NOT corrupted
# Immature (780).jpg: NOT corrupted
# Immature (781).jpg: NOT corrupted
# Immature (782).jpg: NOT corrupted
# Immature (783).jpg: NOT corrupted
# Immature (784).jpg: NOT corrupted
# Immature (785).jpg: NOT corrupted
# Immature (786).jpg: NOT corrupted
# Immature (787).jpg: NOT corrupted
# Immature (788).jpg: NOT corrupted
# Immature (789).jpg: NOT corrupted
# Immature (790).jpg: NOT corrupted
# Immature (791).jpg: NOT corrupted
# Immature (792).jpg: NOT corrupted
# Immature (793).jpg: NOT corrupted
# Immature (794).jpg: NOT corrupted
# Immature (795).jpg: NOT corrupted
# Immature (796).jpg: NOT corrupted
# Immature (797).jpg: NOT corrupted
# Immature (798).jpg: NOT corrupted
# Immature (799).jpg: NOT corrupted
# Immature (800).jpg: NOT corrupted
# Immature (801).jpg: NOT corrupted
# Immature (802).jpg: NOT corrupted
# Immature (803).jpg: NOT corrupted
# Immature (804).jpg: NOT corrupted
# Immature (805).jpg: NOT corrupted
# Immature (806).jpg: NOT corrupted
# Immature (807).jpg: NOT corrupted
# Immature (808).jpg: NOT corrupted
# Immature (809).jpg: NOT corrupted
# Immature (810).jpg: NOT corrupted
# Immature (811).jpg: NOT corrupted
# Immature (812).jpg: NOT corrupted
# Immature (813).jpg: NOT corrupted
# Immature (814).jpg: NOT corrupted
# Immature (815).jpg: NOT corrupted
# Immature (816).jpg: NOT corrupted
# Immature (817).jpg: NOT corrupted
# Immature (818).jpg: NOT corrupted
# Immature (819).jpg: NOT corrupted
# Immature (820).jpg: NOT corrupted
# Immature (821).jpg: NOT corrupted
# Immature (822).jpg: NOT corrupted
# Immature (823).jpg: NOT corrupted
# Immature (824).jpg: NOT corrupted
# Immature (825).jpg: NOT corrupted
# Immature (826).jpg: NOT corrupted
# Immature (827).jpg: NOT corrupted
# Immature (828).jpg: NOT corrupted
# Immature (829).jpg: NOT corrupted
# Immature (830).jpg: NOT corrupted
# Immature (831).jpg: NOT corrupted
# Immature (832).jpg: NOT corrupted
# Immature (833).jpg: NOT corrupted
# Immature (834).jpg: NOT corrupted
# Immature (835).jpg: NOT corrupted
# Immature (836).jpg: NOT corrupted
# Immature (837).jpg: NOT corrupted
# Immature (838).jpg: NOT corrupted
# Immature (839).jpg: NOT corrupted
# Immature (840).jpg: NOT corrupted
# Immature (841).jpg: NOT corrupted
# Immature (842).jpg: NOT corrupted
# Immature (843).jpg: NOT corrupted
# Immature (844).jpg: NOT corrupted
# Immature (845).jpg: NOT corrupted
# Immature (846).jpg: NOT corrupted
# Immature (847).jpg: NOT corrupted
# Immature (848).jpg: NOT corrupted
# Immature (849).jpg: NOT corrupted
# Immature (850).jpg: NOT corrupted
# Immature (851).jpg: NOT corrupted
# Immature (852).jpg: NOT corrupted
# Immature (853).jpg: NOT corrupted
# Immature (854).jpg: NOT corrupted
# Immature (855).jpg: NOT corrupted
# Immature (856).jpg: NOT corrupted
# Immature (857).jpg: NOT corrupted
# Immature (858).jpg: NOT corrupted
# Immature (859).jpg: NOT corrupted
# Immature (860).jpg: NOT corrupted
# Immature (861).jpg: NOT corrupted
# Immature (862).jpg: NOT corrupted
# Immature (863).jpg: NOT corrupted
# Immature (864).jpg: NOT corrupted
# Immature (865).jpg: NOT corrupted
# Immature (866).jpg: NOT corrupted
# Immature (867).jpg: NOT corrupted
# Immature (868).jpg: NOT corrupted
# Immature (869).jpg: NOT corrupted
# Immature (870).jpg: NOT corrupted
# Immature (871).jpg: NOT corrupted
# Immature (872).jpg: NOT corrupted
# Immature (873).jpg: NOT corrupted
# Immature (874).jpg: NOT corrupted
# Immature (875).jpg: NOT corrupted
# Immature (876).jpg: NOT corrupted
# Immature (877).jpg: NOT corrupted
# Immature (878).jpg: NOT corrupted
# Immature (879).jpg: NOT corrupted
# Immature (880).jpg: NOT corrupted
# Immature (881).jpg: NOT corrupted
# Immature (882).jpg: NOT corrupted
# Immature (883).jpg: NOT corrupted
# Immature (884).jpg: NOT corrupted
# Immature (885).jpg: NOT corrupted
# Immature (886).jpg: NOT corrupted
# Immature (887).jpg: NOT corrupted
# Immature (888).jpg: NOT corrupted
# Immature (889).jpg: NOT corrupted
# Immature (890).jpg: NOT corrupted
# Immature (891).jpg: NOT corrupted
# Immature (892).jpg: NOT corrupted
# Immature (893).jpg: NOT corrupted
# Immature (894).jpg: NOT corrupted
# Immature (895).jpg: NOT corrupted
# Immature (896).jpg: NOT corrupted
# Immature (897).jpg: NOT corrupted
# Immature (898).jpg: NOT corrupted
# Immature (899).jpg: NOT corrupted
# Immature (900).jpg: NOT corrupted
# Immature (901).jpg: NOT corrupted
# Immature (902).jpg: NOT corrupted
# Immature (903).jpg: NOT corrupted
# Immature (904).jpg: NOT corrupted
# Immature (905).jpg: NOT corrupted
# Immature (906).jpg: NOT corrupted
# Immature (907).jpg: NOT corrupted
# Immature (908).jpg: NOT corrupted
# Immature (909).jpg: NOT corrupted
# Immature (910).jpg: NOT corrupted
# Immature (911).jpg: NOT corrupted
# Immature (912).jpg: NOT corrupted
# Immature (913).jpg: NOT corrupted
# Immature (914).jpg: NOT corrupted
# Immature (915).jpg: NOT corrupted
# Immature (916).jpg: NOT corrupted
# Immature (917).jpg: NOT corrupted
# Immature (918).jpg: NOT corrupted
# Immature (919).jpg: NOT corrupted
# Immature (920).jpg: NOT corrupted
# Immature (921).jpg: NOT corrupted
# Immature (922).jpg: NOT corrupted
# Immature (923).jpg: NOT corrupted
# Immature (924).jpg: NOT corrupted
# Immature (925).jpg: NOT corrupted
# Immature (926).jpg: NOT corrupted
# Immature (927).jpg: NOT corrupted
# Immature (928).jpg: NOT corrupted
# Immature (929).jpg: NOT corrupted
# Immature (930).jpg: NOT corrupted
# Immature (931).jpg: NOT corrupted
# Immature (932).jpg: NOT corrupted
# Immature (933).jpg: NOT corrupted
# Immature (934).jpg: NOT corrupted
# Immature (935).jpg: NOT corrupted
# Immature (936).jpg: NOT corrupted
# Immature (937).jpg: NOT corrupted
# Immature (938).jpg: NOT corrupted
# Immature (939).jpg: NOT corrupted
# Immature (940).jpg: NOT corrupted
# Immature (941).jpg: NOT corrupted
# Immature (942).jpg: NOT corrupted
# Immature (943).jpg: NOT corrupted
# Immature (944).jpg: NOT corrupted
# Immature (945).jpg: NOT corrupted
# Immature (946).jpg: NOT corrupted
# Immature (947).jpg: NOT corrupted
# Immature (948).jpg: NOT corrupted
# Immature (949).jpg: NOT corrupted
# Immature (950).jpg: NOT corrupted
# Immature (951).jpg: NOT corrupted
# Immature (952).jpg: NOT corrupted
# Immature (953).jpg: NOT corrupted
# Immature (954).jpg: NOT corrupted
# Immature (955).jpg: NOT corrupted
# Immature (956).jpg: NOT corrupted
# Immature (957).jpg: NOT corrupted
# Immature (958).jpg: NOT corrupted
# Immature (959).jpg: NOT corrupted
# Immature (960).jpg: NOT corrupted
# Immature (961).jpg: NOT corrupted
# Immature (962).jpg: NOT corrupted
# Immature (963).jpg: NOT corrupted
# Immature (964).jpg: NOT corrupted
# Immature (965).jpg: NOT corrupted
# Immature (966).jpg: NOT corrupted
# Immature (967).jpg: NOT corrupted
# Immature (968).jpg: NOT corrupted
# Immature (969).jpg: NOT corrupted
# Immature (970).jpg: NOT corrupted
# Immature (971).jpg: NOT corrupted
# Immature (972).jpg: NOT corrupted
# Immature (973).jpg: NOT corrupted
# Immature (974).jpg: NOT corrupted
# Immature (975).jpg: NOT corrupted
# Immature (976).jpg: NOT corrupted
# Immature (977).jpg: NOT corrupted
# Immature (978).jpg: NOT corrupted
# Immature (979).jpg: NOT corrupted
# Immature (980).jpg: NOT corrupted
# Immature (981).jpg: NOT corrupted
# Immature (982).jpg: NOT corrupted
# Immature (983).jpg: NOT corrupted
# Immature (984).jpg: NOT corrupted
# Immature (985).jpg: NOT corrupted
# Immature (986).jpg: NOT corrupted
# Immature (987).jpg: NOT corrupted
# Immature (988).jpg: NOT corrupted
# Immature (989).jpg: NOT corrupted
# Immature (990).jpg: NOT corrupted
# Immature (991).jpg: NOT corrupted
# Immature (992).jpg: NOT corrupted
# Immature (993).jpg: NOT corrupted
# Immature (994).jpg: NOT corrupted
# Immature (995).jpg: NOT corrupted
# Immature (996).jpg: NOT corrupted
# Immature (997).jpg: NOT corrupted
# Immature (998).jpg: NOT corrupted
# Immature (999).jpg: NOT corrupted
# Immature (1000).jpg: NOT corrupted
# Immature (1001).jpg: NOT corrupted
# Immature (1002).jpg: NOT corrupted
# Immature (1003).jpg: NOT corrupted
# Immature (1004).jpg: NOT corrupted
# Immature (1005).jpg: NOT corrupted
# Immature (1006).jpg: NOT corrupted
# Immature (1007).jpg: NOT corrupted
# Immature (1008).jpg: NOT corrupted
# Immature (1009).jpg: NOT corrupted
# Immature (1010).jpg: NOT corrupted
# Immature (1011).jpg: NOT corrupted
# Immature (1012).jpg: NOT corrupted
# Immature (1013).jpg: NOT corrupted
# Immature (1014).jpg: NOT corrupted
# Immature (1015).jpg: NOT corrupted
# Immature (1016).jpg: NOT corrupted
# Immature (1017).jpg: NOT corrupted
# Immature (1018).jpg: NOT corrupted
# Immature (1019).jpg: NOT corrupted
# Immature (1020).jpg: NOT corrupted
# Immature (1021).jpg: NOT corrupted
# Immature (1022).jpg: NOT corrupted
# Immature (1023).jpg: NOT corrupted
# Immature (1024).jpg: NOT corrupted
# Immature (1025).jpg: NOT corrupted
# Immature (1026).jpg: NOT corrupted
# Immature (1027).jpg: NOT corrupted
# Immature (1028).jpg: NOT corrupted
# Immature (1029).jpg: NOT corrupted
# Immature (1030).jpg: NOT corrupted
# Immature (1031).jpg: NOT corrupted
# Immature (1032).jpg: NOT corrupted
# Immature (1033).jpg: NOT corrupted
# Immature (1034).jpg: NOT corrupted
# Immature (1035).jpg: NOT corrupted
# Immature (1036).jpg: NOT corrupted
# Immature (1037).jpg: NOT corrupted
# Immature (1038).jpg: NOT corrupted
# Immature (1039).jpg: NOT corrupted
# Immature (1040).jpg: NOT corrupted
# Immature (1041).jpg: NOT corrupted
# Immature (1042).jpg: NOT corrupted
# Immature (1043).jpg: NOT corrupted
# Immature (1044).jpg: NOT corrupted
# Immature (1045).jpg: NOT corrupted
# Immature (1046).jpg: NOT corrupted
# Immature (1047).jpg: NOT corrupted
# Immature (1048).jpg: NOT corrupted
# Immature (1049).jpg: NOT corrupted
# Immature (1050).jpg: NOT corrupted
# Immature (1051).jpg: NOT corrupted
# Immature (1052).jpg: NOT corrupted
# Immature (1053).jpg: NOT corrupted
# Immature (1054).jpg: NOT corrupted
# Immature (1055).jpg: NOT corrupted
# Immature (1056).jpg: NOT corrupted
# Immature (1057).jpg: NOT corrupted
# Immature (1058).jpg: NOT corrupted
# Immature (1059).jpg: NOT corrupted
# Immature (1060).jpg: NOT corrupted
# Immature (1061).jpg: NOT corrupted
# Immature (1062).jpg: NOT corrupted
# Immature (1063).jpg: NOT corrupted
# Immature (1064).jpg: NOT corrupted
# Immature (1065).jpg: NOT corrupted
# Immature (1066).jpg: NOT corrupted
# Immature (1067).jpg: NOT corrupted
# Immature (1068).jpg: NOT corrupted
# Immature (1069).jpg: NOT corrupted
# Immature (1070).jpg: NOT corrupted
# Immature (1071).jpg: NOT corrupted
# Immature (1072).jpg: NOT corrupted
# Immature (1073).jpg: NOT corrupted
# Immature (1074).jpg: NOT corrupted
# Immature (1075).jpg: NOT corrupted
# Immature (1076).jpg: NOT corrupted
# Immature (1077).jpg: NOT corrupted
# Immature (1078).jpg: NOT corrupted
# Immature (1079).jpg: NOT corrupted
# Immature (1080).jpg: NOT corrupted
# Immature (1081).jpg: NOT corrupted
# Immature (1082).jpg: NOT corrupted
# Immature (1083).jpg: NOT corrupted
# Immature (1084).jpg: NOT corrupted
# Immature (1085).jpg: NOT corrupted
# Immature (1086).jpg: NOT corrupted
# Immature (1087).jpg: NOT corrupted
# Immature (1088).jpg: NOT corrupted
# Immature (1089).jpg: NOT corrupted
# Immature (1090).jpg: NOT corrupted
# Immature (1091).jpg: NOT corrupted
# Immature (1092).jpg: NOT corrupted
# Immature (1093).jpg: NOT corrupted
# Immature (1094).jpg: NOT corrupted
# Immature (1095).jpg: NOT corrupted
# Immature (1096).jpg: NOT corrupted
# Immature (1097).jpg: NOT corrupted
# Immature (1098).jpg: NOT corrupted
# Immature (1099).jpg: NOT corrupted
# Immature (1100).jpg: NOT corrupted
# Immature (1101).jpg: NOT corrupted
# Immature (1102).jpg: NOT corrupted
# Immature (1103).jpg: NOT corrupted
# Immature (1104).jpg: NOT corrupted
# Immature (1105).jpg: NOT corrupted
# Immature (1106).jpg: NOT corrupted
# Immature (1107).jpg: NOT corrupted
# Immature (1108).jpg: NOT corrupted
# Immature (1109).jpg: NOT corrupted
# Immature (1110).jpg: NOT corrupted
# Immature (1111).jpg: NOT corrupted
# Immature (1112).jpg: NOT corrupted
# Immature (1113).jpg: NOT corrupted
# Immature (1114).jpg: NOT corrupted
# Immature (1115).jpg: NOT corrupted
# Immature (1116).jpg: NOT corrupted
# Immature (1117).jpg: NOT corrupted
# Immature (1118).jpg: NOT corrupted
# Immature (1119).jpg: NOT corrupted
# Immature (1120).jpg: NOT corrupted
# Immature (1121).jpg: NOT corrupted
# Immature (1122).jpg: NOT corrupted
# Immature (1123).jpg: NOT corrupted
# Immature (1124).jpg: NOT corrupted
# Immature (1125).jpg: NOT corrupted
# Immature (1126).jpg: NOT corrupted
# Immature (1127).jpg: NOT corrupted
# Immature (1128).jpg: NOT corrupted
# Immature (1129).jpg: NOT corrupted
# Immature (1130).jpg: NOT corrupted
# Immature (1131).jpg: NOT corrupted
# Immature (1132).jpg: NOT corrupted
# Immature (1133).jpg: NOT corrupted
# Immature (1134).jpg: NOT corrupted
# Immature (1135).jpg: NOT corrupted
# Immature (1136).jpg: NOT corrupted
# Immature (1137).jpg: NOT corrupted
# Immature (1138).jpg: NOT corrupted
# Immature (1139).jpg: NOT corrupted
# Immature (1140).jpg: NOT corrupted
# Immature (1141).jpg: NOT corrupted
# Immature (1142).jpg: NOT corrupted
# Immature (1143).jpg: NOT corrupted
# Immature (1144).jpg: NOT corrupted
# Immature (1145).jpg: NOT corrupted
# Immature (1146).jpg: NOT corrupted
# Immature (1147).jpg: NOT corrupted
# Immature (1148).jpg: NOT corrupted
# Immature (1149).jpg: NOT corrupted
# Immature (1150).jpg: NOT corrupted
# Immature (1151).jpg: NOT corrupted
# Immature (1152).jpg: NOT corrupted
# Immature (1153).jpg: NOT corrupted
# Immature (1154).jpg: NOT corrupted
# Immature (1155).jpg: NOT corrupted
# Immature (1156).jpg: NOT corrupted
# Immature (1157).jpg: NOT corrupted
# Immature (1158).jpg: NOT corrupted
# Immature (1159).jpg: NOT corrupted
# Immature (1160).jpg: NOT corrupted
# Immature (1161).jpg: NOT corrupted
# Immature (1162).jpg: NOT corrupted
# Immature (1163).jpg: NOT corrupted
# Immature (1164).jpg: NOT corrupted
# Immature (1165).jpg: NOT corrupted
# Immature (1166).jpg: NOT corrupted
# Immature (1167).jpg: NOT corrupted
# Immature (1168).jpg: NOT corrupted
# Immature (1169).jpg: NOT corrupted
# Immature (1170).jpg: NOT corrupted
# Immature (1171).jpg: NOT corrupted
# Immature (1172).jpg: NOT corrupted
# Immature (1173).jpg: NOT corrupted
# Immature (1174).jpg: NOT corrupted
# Immature (1175).jpg: NOT corrupted
# Immature (1176).jpg: NOT corrupted
# Immature (1177).jpg: NOT corrupted
# Immature (1178).jpg: NOT corrupted
# Immature (1179).jpg: NOT corrupted
# Immature (1180).jpg: NOT corrupted
# Immature (1181).jpg: NOT corrupted
# Immature (1182).jpg: NOT corrupted
# Immature (1183).jpg: NOT corrupted
# Immature (1184).jpg: NOT corrupted
# Immature (1185).jpg: NOT corrupted
# Immature (1186).jpg: NOT corrupted
# Immature (1187).jpg: NOT corrupted
# Immature (1188).jpg: NOT corrupted
# Immature (1189).jpg: NOT corrupted
# Immature (1190).jpg: NOT corrupted
# Immature (1191).jpg: NOT corrupted
# Immature (1192).jpg: NOT corrupted
# Immature (1193).jpg: NOT corrupted
# Immature (1194).jpg: NOT corrupted
# Immature (1195).jpg: NOT corrupted
# Immature (1196).jpg: NOT corrupted
# Immature (1197).jpg: NOT corrupted
# Immature (1198).jpg: NOT corrupted
# Immature (1199).jpg: NOT corrupted
# Immature (1200).jpg: NOT corrupted
# Immature (1201).jpg: NOT corrupted
# Immature (1202).jpg: NOT corrupted
# Immature (1203).jpg: NOT corrupted
# Immature (1204).jpg: NOT corrupted
# Immature (1205).jpg: NOT corrupted
# Immature (1206).jpg: NOT corrupted
# Immature (1207).jpg: NOT corrupted
# Immature (1208).jpg: NOT corrupted
# Immature (1209).jpg: NOT corrupted
# Immature (1210).jpg: NOT corrupted
# Immature (1211).jpg: NOT corrupted
# Immature (1212).jpg: NOT corrupted
# Immature (1213).jpg: NOT corrupted
# Immature (1214).jpg: NOT corrupted
# Immature (1215).jpg: NOT corrupted
# Immature (1216).jpg: NOT corrupted
# Immature (1217).jpg: NOT corrupted
# Immature (1218).jpg: NOT corrupted
# Immature (1219).jpg: NOT corrupted
# Immature (1220).jpg: NOT corrupted
# Immature (1221).jpg: NOT corrupted
# Immature (1222).jpg: NOT corrupted
# Immature (1223).jpg: NOT corrupted
# Immature (1224).jpg: NOT corrupted
# Immature (1225).jpg: NOT corrupted
# Immature (1226).jpg: NOT corrupted
# Immature (1227).jpg: NOT corrupted
# Immature (1228).jpg: NOT corrupted
# Immature (1229).jpg: NOT corrupted
# Immature (1230).jpg: NOT corrupted
# Immature (1231).jpg: NOT corrupted
# Immature (1232).jpg: NOT corrupted
# Immature (1233).jpg: NOT corrupted
# Immature (1234).jpg: NOT corrupted
# Immature (1235).jpg: NOT corrupted
# Immature (1236).jpg: NOT corrupted
# Immature (1237).jpg: NOT corrupted
# Immature (1238).jpg: NOT corrupted
# Immature (1239).jpg: NOT corrupted
# Immature (1240).jpg: NOT corrupted
# Immature (1241).jpg: NOT corrupted
# Immature (1242).jpg: NOT corrupted
# Immature (1243).jpg: NOT corrupted
# Immature (1244).jpg: NOT corrupted
# Immature (1245).jpg: NOT corrupted
# Immature (1246).jpg: NOT corrupted
# Immature (1247).jpg: NOT corrupted
# Immature (1248).jpg: NOT corrupted
# Immature (1249).jpg: NOT corrupted
# Immature (1250).jpg: NOT corrupted
# Immature (1251).jpg: NOT corrupted
# Immature (1252).jpg: NOT corrupted
# Immature (1253).jpg: NOT corrupted
# Immature (1254).jpg: NOT corrupted
# Immature (1255).jpg: NOT corrupted
# Immature (1256).jpg: NOT corrupted
# Immature (1257).jpg: NOT corrupted
# Immature (1258).jpg: NOT corrupted
# Immature (1259).jpg: NOT corrupted
# Immature (1260).jpg: NOT corrupted
# Immature (1261).jpg: NOT corrupted
# Immature (1262).jpg: NOT corrupted
# Immature (1263).jpg: NOT corrupted
# Immature (1264).jpg: NOT corrupted
# Immature (1265).jpg: NOT corrupted
# Immature (1266).jpg: NOT corrupted
# Immature (1267).jpg: NOT corrupted
# Immature (1268).jpg: NOT corrupted
# Immature (1269).jpg: NOT corrupted
# Immature (1270).jpg: NOT corrupted
# Immature (1271).jpg: NOT corrupted
# Immature (1272).jpg: NOT corrupted
# Immature (1273).jpg: NOT corrupted
# Immature (1274).jpg: NOT corrupted
# Immature (1275).jpg: NOT corrupted
# Immature (1276).jpg: NOT corrupted
# Immature (1277).jpg: NOT corrupted
# Immature (1278).jpg: NOT corrupted
# Immature (1279).jpg: NOT corrupted
# Immature (1280).jpg: NOT corrupted
# Immature (1281).jpg: NOT corrupted
# Immature (1282).jpg: NOT corrupted
# Immature (1283).jpg: NOT corrupted
# Immature (1284).jpg: NOT corrupted
# Immature (1285).jpg: NOT corrupted
# Immature (1286).jpg: NOT corrupted
# Immature (1287).jpg: NOT corrupted
# Immature (1288).jpg: NOT corrupted
# Immature (1289).jpg: NOT corrupted
# Immature (1290).jpg: NOT corrupted
# Immature (1291).jpg: NOT corrupted
# Immature (1292).jpg: NOT corrupted
# Immature (1293).jpg: NOT corrupted
# Immature (1294).jpg: NOT corrupted
# Immature (1295).jpg: NOT corrupted
# Immature (1296).jpg: NOT corrupted
# Immature (1297).jpg: NOT corrupted
# Immature (1298).jpg: NOT corrupted
# Immature (1299).jpg: NOT corrupted
# Immature (1300).jpg: NOT corrupted
# Immature (1301).jpg: NOT corrupted
# Immature (1302).jpg: NOT corrupted
# Immature (1303).jpg: NOT corrupted
# Immature (1304).jpg: NOT corrupted
# Immature (1305).jpg: NOT corrupted
# Immature (1306).jpg: NOT corrupted
# Immature (1307).jpg: NOT corrupted
# Immature (1308).jpg: NOT corrupted
# Immature (1309).jpg: NOT corrupted
# Immature (1310).jpg: NOT corrupted
# Immature (1311).jpg: NOT corrupted
# Immature (1312).jpg: NOT corrupted
# Immature (1313).jpg: NOT corrupted
# Immature (1314).jpg: NOT corrupted
# Immature (1315).jpg: NOT corrupted
# Immature (1316).jpg: NOT corrupted
# Immature (1317).jpg: NOT corrupted
# Immature (1).jpg: NOT corrupted
# Immature (2).jpg: NOT corrupted
# Immature (3).jpg: NOT corrupted
# Immature (4).jpg: NOT corrupted
# Immature (5).jpg: NOT corrupted
# Immature (6).jpg: NOT corrupted
# Immature (7).jpg: NOT corrupted
# Immature (8).jpg: NOT corrupted
# Immature (9).jpg: NOT corrupted
# Immature (10).jpg: NOT corrupted
# Immature (11).jpg: NOT corrupted
# Immature (12).jpg: NOT corrupted
# Immature (13).jpg: NOT corrupted
# Immature (14).jpg: NOT corrupted
# Immature (15).jpg: NOT corrupted
# Immature (16).jpg: NOT corrupted
# Immature (17).jpg: NOT corrupted
# Immature (18).jpg: NOT corrupted
# Immature (19).jpg: NOT corrupted
# Immature (20).jpg: NOT corrupted
# Immature (21).jpg: NOT corrupted
# Immature (22).jpg: NOT corrupted
# Immature (23).jpg: NOT corrupted
# Immature (24).jpg: NOT corrupted
# Immature (25).jpg: NOT corrupted
# Immature (26).jpg: NOT corrupted
# Immature (27).jpg: NOT corrupted
# Immature (28).jpg: NOT corrupted
# Immature (29).jpg: NOT corrupted
# Immature (30).jpg: NOT corrupted
# Immature (31).jpg: NOT corrupted
# Immature (32).jpg: NOT corrupted
# Immature (33).jpg: NOT corrupted
# Immature (34).jpg: NOT corrupted
# Immature (35).jpg: NOT corrupted
# Immature (36).jpg: NOT corrupted
# Immature (37).jpg: NOT corrupted
# Immature (38).jpg: NOT corrupted
# Immature (39).jpg: NOT corrupted
# Immature (40).jpg: NOT corrupted
# Immature (41).jpg: NOT corrupted
# Immature (42).jpg: NOT corrupted
# Immature (43).jpg: NOT corrupted
# Immature (44).jpg: NOT corrupted
# Immature (45).jpg: NOT corrupted
# Immature (46).jpg: NOT corrupted
# Immature (47).jpg: NOT corrupted
# Immature (48).jpg: NOT corrupted
# Immature (49).jpg: NOT corrupted
# Immature (50).jpg: NOT corrupted
# Immature (51).jpg: NOT corrupted
# Immature (52).jpg: NOT corrupted
# Immature (53).jpg: NOT corrupted
# Immature (54).jpg: NOT corrupted
# Immature (55).jpg: NOT corrupted
# Immature (56).jpg: NOT corrupted
# Immature (57).jpg: NOT corrupted
# Immature (58).jpg: NOT corrupted
# Immature (59).jpg: NOT corrupted
# Immature (60).jpg: NOT corrupted
# Immature (61).jpg: NOT corrupted
# Immature (62).jpg: NOT corrupted
# Immature (63).jpg: NOT corrupted
# Immature (64).jpg: NOT corrupted
# Immature (65).jpg: NOT corrupted
# Immature (66).jpg: NOT corrupted
# Immature (67).jpg: NOT corrupted
# Immature (68).jpg: NOT corrupted
# Immature (69).jpg: NOT corrupted
# Immature (70).jpg: NOT corrupted
# Immature (71).jpg: NOT corrupted
# Immature (72).jpg: NOT corrupted
# Immature (73).jpg: NOT corrupted
# Immature (74).jpg: NOT corrupted
# Immature (75).jpg: NOT corrupted
# Immature (76).jpg: NOT corrupted
# Immature (77).jpg: NOT corrupted
# Immature (78).jpg: NOT corrupted
# Immature (79).jpg: NOT corrupted
# Immature (80).jpg: NOT corrupted
# Immature (81).jpg: NOT corrupted
# Immature (82).jpg: NOT corrupted
# Immature (83).jpg: NOT corrupted
# Immature (84).jpg: NOT corrupted
# Immature (85).jpg: NOT corrupted
# Immature (86).jpg: NOT corrupted
# Immature (87).jpg: NOT corrupted
# Immature (88).jpg: NOT corrupted
# Immature (89).jpg: NOT corrupted
# Immature (90).jpg: NOT corrupted
# Immature (91).jpg: NOT corrupted
# Immature (92).jpg: NOT corrupted
# Immature (93).jpg: NOT corrupted
# Immature (94).jpg: NOT corrupted
# Immature (95).jpg: NOT corrupted
# Immature (96).jpg: NOT corrupted
# Immature (97).jpg: NOT corrupted
# Immature (98).jpg: NOT corrupted
# Immature (99).jpg: NOT corrupted
# Immature (100).jpg: NOT corrupted
# Immature (101).jpg: NOT corrupted
# Immature (102).jpg: NOT corrupted
# Immature (103).jpg: NOT corrupted
# Immature (104).jpg: NOT corrupted
# Immature (105).jpg: NOT corrupted
# Immature (106).jpg: NOT corrupted
# Immature (107).jpg: NOT corrupted
# Immature (108).jpg: NOT corrupted
# Immature (109).jpg: NOT corrupted
# Immature (110).jpg: NOT corrupted
# Immature (111).jpg: NOT corrupted
# Immature (112).jpg: NOT corrupted
# Immature (113).jpg: NOT corrupted
# Immature (114).jpg: NOT corrupted
# Immature (115).jpg: NOT corrupted
# Immature (116).jpg: NOT corrupted
# Immature (117).jpg: NOT corrupted
# Immature (118).jpg: NOT corrupted
# Immature (119).jpg: NOT corrupted
# Immature (120).jpg: NOT corrupted
# Immature (121).jpg: NOT corrupted
# Immature (122).jpg: NOT corrupted
# Immature (123).jpg: NOT corrupted
# Immature (124).jpg: NOT corrupted
# Immature (125).jpg: NOT corrupted
# Immature (126).jpg: NOT corrupted
# Immature (127).jpg: NOT corrupted
# Immature (128).jpg: NOT corrupted
# Immature (129).jpg: NOT corrupted
# Immature (130).jpg: NOT corrupted
# Immature (131).jpg: NOT corrupted
# Immature (132).jpg: NOT corrupted
# Immature (133).jpg: NOT corrupted
# Immature (134).jpg: NOT corrupted
# Immature (135).jpg: NOT corrupted
# Immature (136).jpg: NOT corrupted
# Immature (137).jpg: NOT corrupted
# Immature (138).jpg: NOT corrupted
# Immature (139).jpg: NOT corrupted
# Immature (140).jpg: NOT corrupted
# Immature (141).jpg: NOT corrupted
# Immature (142).jpg: NOT corrupted
# Immature (143).jpg: NOT corrupted
# Immature (144).jpg: NOT corrupted
# Immature (145).jpg: NOT corrupted
# Immature (146).jpg: NOT corrupted
# Immature (147).jpg: NOT corrupted
# Immature (148).jpg: NOT corrupted
# Immature (149).jpg: NOT corrupted
# Immature (150).jpg: NOT corrupted
# Immature (151).jpg: NOT corrupted
# Immature (152).jpg: NOT corrupted
# Immature (153).jpg: NOT corrupted
# Immature (154).jpg: NOT corrupted
# Immature (155).jpg: NOT corrupted
# Immature (156).jpg: NOT corrupted
# Immature (157).jpg: NOT corrupted
# Immature (158).jpg: NOT corrupted
# Immature (159).jpg: NOT corrupted
# Immature (160).jpg: NOT corrupted
# Immature (161).jpg: NOT corrupted
# Immature (162).jpg: NOT corrupted
# Immature (163).jpg: NOT corrupted
# Immature (164).jpg: NOT corrupted
# Immature (165).jpg: NOT corrupted
# Immature (166).jpg: NOT corrupted
# Immature (167).jpg: NOT corrupted
# Immature (168).jpg: NOT corrupted
# Immature (169).jpg: NOT corrupted
# Immature (170).jpg: NOT corrupted
# Immature (171).jpg: NOT corrupted
# Immature (172).jpg: NOT corrupted
# Immature (173).jpg: NOT corrupted
# Immature (174).jpg: NOT corrupted
# Immature (175).jpg: NOT corrupted
# Immature (176).jpg: NOT corrupted
# Immature (177).jpg: NOT corrupted
# Immature (178).jpg: NOT corrupted
# Immature (179).jpg: NOT corrupted
# Immature (180).jpg: NOT corrupted
# Immature (181).jpg: NOT corrupted
# Immature (182).jpg: NOT corrupted
# Immature (183).jpg: NOT corrupted
# Immature (184).jpg: NOT corrupted
# Immature (185).jpg: NOT corrupted
# Immature (186).jpg: NOT corrupted
# Immature (187).jpg: NOT corrupted
# Immature (188).jpg: NOT corrupted
# Immature (189).jpg: NOT corrupted
# Immature (190).jpg: NOT corrupted
# Immature (191).jpg: NOT corrupted
# Immature (192).jpg: NOT corrupted
# Immature (193).jpg: NOT corrupted
# Immature (194).jpg: NOT corrupted
# Immature (195).jpg: NOT corrupted
# Immature (196).jpg: NOT corrupted
# Immature (197).jpg: NOT corrupted
# Immature (198).jpg: NOT corrupted
# Immature (199).jpg: NOT corrupted
# Immature (200).jpg: NOT corrupted
# Immature (201).jpg: NOT corrupted
# Immature (202).jpg: NOT corrupted
# Immature (203).jpg: NOT corrupted
# Immature (204).jpg: NOT corrupted
# Immature (205).jpg: NOT corrupted
# Immature (206).jpg: NOT corrupted
# Immature (207).jpg: NOT corrupted
# Immature (208).jpg: NOT corrupted
# Immature (209).jpg: NOT corrupted
# Immature (210).jpg: NOT corrupted
# Immature (211).jpg: NOT corrupted
# Immature (212).jpg: NOT corrupted
# Immature (213).jpg: NOT corrupted
# Immature (214).jpg: NOT corrupted
# Immature (215).jpg: NOT corrupted
# Immature (216).jpg: NOT corrupted
# Immature (217).jpg: NOT corrupted
# Immature (218).jpg: NOT corrupted
# Immature (219).jpg: NOT corrupted
# Immature (220).jpg: NOT corrupted
# Immature (221).jpg: NOT corrupted
# Immature (222).jpg: NOT corrupted
# Immature (223).jpg: NOT corrupted
# Immature (224).jpg: NOT corrupted
# Immature (225).jpg: NOT corrupted
# Immature (226).jpg: NOT corrupted
# Immature (227).jpg: NOT corrupted
# Immature (228).jpg: NOT corrupted
# Immature (229).jpg: NOT corrupted
# Immature (230).jpg: NOT corrupted
# Immature (231).jpg: NOT corrupted
# Immature (232).jpg: NOT corrupted
# Immature (233).jpg: NOT corrupted
# Immature (234).jpg: NOT corrupted
# Immature (235).jpg: NOT corrupted
# Immature (236).jpg: NOT corrupted
# Immature (237).jpg: NOT corrupted
# Immature (238).jpg: NOT corrupted
# Immature (239).jpg: NOT corrupted
# Immature (240).jpg: NOT corrupted
# Immature (241).jpg: NOT corrupted
# Immature (242).jpg: NOT corrupted
# Immature (243).jpg: NOT corrupted
# Immature (244).jpg: NOT corrupted
# Immature (245).jpg: NOT corrupted
# Immature (246).jpg: NOT corrupted
# Immature (247).jpg: NOT corrupted
# Immature (248).jpg: NOT corrupted
# Immature (249).jpg: NOT corrupted
# Immature (250).jpg: NOT corrupted
# Immature (251).jpg: NOT corrupted
# Immature (252).jpg: NOT corrupted
# Immature (253).jpg: NOT corrupted
# Immature (254).jpg: NOT corrupted
# Immature (255).jpg: NOT corrupted
# Immature (256).jpg: NOT corrupted
# Immature (257).jpg: NOT corrupted
# Immature (258).jpg: NOT corrupted
# Immature (259).jpg: NOT corrupted
# Immature (260).jpg: NOT corrupted
# Immature (261).jpg: NOT corrupted
# Immature (262).jpg: NOT corrupted
# Immature (263).jpg: NOT corrupted
# Immature (264).jpg: NOT corrupted
# Immature (265).jpg: NOT corrupted
# Immature (266).jpg: NOT corrupted
# Immature (267).jpg: NOT corrupted
# Immature (268).jpg: NOT corrupted
# Immature (269).jpg: NOT corrupted
# Immature (270).jpg: NOT corrupted
# Immature (271).jpg: NOT corrupted
# Immature (272).jpg: NOT corrupted
# Immature (273).jpg: NOT corrupted
# Immature (274).jpg: NOT corrupted
# Immature (275).jpg: NOT corrupted
# Immature (276).jpg: NOT corrupted
# Immature (277).jpg: NOT corrupted
# Immature (278).jpg: NOT corrupted
# Immature (279).jpg: NOT corrupted
# Immature (280).jpg: NOT corrupted
# Immature (281).jpg: NOT corrupted
# Immature (282).jpg: NOT corrupted
# Immature (283).jpg: NOT corrupted
# Immature (284).jpg: NOT corrupted
# Immature (285).jpg: NOT corrupted
# Immature (286).jpg: NOT corrupted
# Immature (287).jpg: NOT corrupted
# Immature (288).jpg: NOT corrupted
# Immature (289).jpg: NOT corrupted
# Immature (290).jpg: NOT corrupted
# Immature (291).jpg: NOT corrupted
# Immature (292).jpg: NOT corrupted
# Immature (293).jpg: NOT corrupted
# Immature (294).jpg: NOT corrupted
# Immature (295).jpg: NOT corrupted
# Immature (296).jpg: NOT corrupted
# Immature (297).jpg: NOT corrupted
# Immature (298).jpg: NOT corrupted
# Immature (299).jpg: NOT corrupted
# Immature (300).jpg: NOT corrupted
# Immature (301).jpg: NOT corrupted
# Immature (302).jpg: NOT corrupted
# Immature (303).jpg: NOT corrupted
# Immature (304).jpg: NOT corrupted
# Immature (305).jpg: NOT corrupted
# Immature (306).jpg: NOT corrupted
# Immature (307).jpg: NOT corrupted
# Immature (308).jpg: NOT corrupted
# Immature (309).jpg: NOT corrupted
# Immature (310).jpg: NOT corrupted
# Immature (311).jpg: NOT corrupted
# Immature (312).jpg: NOT corrupted
# Immature (313).jpg: NOT corrupted
# Immature (314).jpg: NOT corrupted
# Immature (315).jpg: NOT corrupted
# Immature (316).jpg: NOT corrupted
# Immature (317).jpg: NOT corrupted
# /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/train/Mature
# Checking images in directory: /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/train/Mature
# Mature (176).jpg: NOT corrupted
# Mature (50).jpg: NOT corrupted
# Mature (1263).jpg: NOT corrupted
# Mature (150).jpg: NOT corrupted
# Mature (508).jpg: NOT corrupted
# Mature (1004).jpg: NOT corrupted
# Mature (1024).jpg: NOT corrupted
# Mature (468).jpg: NOT corrupted
# Mature (414).jpg: NOT corrupted
# Mature (482).jpg: NOT corrupted
# Mature (286).jpg: NOT corrupted
# Mature (1268).jpg: NOT corrupted
# Mature (1011).jpg: NOT corrupted
# Mature (1242).jpg: NOT corrupted
# Mature (162).jpg: NOT corrupted
# Mature (1221).jpg: NOT corrupted
# Mature (389).jpg: NOT corrupted
# Mature (279).jpg: NOT corrupted
# Mature (1119).jpg: NOT corrupted
# Mature (1058).jpg: NOT corrupted
# Mature (113).jpg: NOT corrupted
# Mature (210).jpg: NOT corrupted
# Mature (497).jpg: NOT corrupted
# Mature (172).jpg: NOT corrupted
# Mature (193).jpg: NOT corrupted
# Mature (513).jpg: NOT corrupted
# Mature (1034).jpg: NOT corrupted
# Mature (347).jpg: NOT corrupted
# Mature (1114).jpg: NOT corrupted
# Mature (228).jpg: NOT corrupted
# Mature (1105).jpg: NOT corrupted
# Mature (307).jpg: NOT corrupted
# Mature (1097).jpg: NOT corrupted
# Mature (1214).jpg: NOT corrupted
# Mature (1175).jpg: NOT corrupted
# Mature (453).jpg: NOT corrupted
# Mature (337).jpg: NOT corrupted
# Mature (1185).jpg: NOT corrupted
# Mature (329).jpg: NOT corrupted
# Mature (518).jpg: NOT corrupted
# Mature (138).jpg: NOT corrupted
# Mature (1188).jpg: NOT corrupted
# Mature (446).jpg: NOT corrupted
# Mature (103).jpg: NOT corrupted
# Mature (471).jpg: NOT corrupted
# Mature (567).jpg: NOT corrupted
# Mature (45).jpg: NOT corrupted
# Mature (1237).jpg: NOT corrupted
# Mature (418).jpg: NOT corrupted
# Mature (232).jpg: NOT corrupted
# Mature (260).jpg: NOT corrupted
# Mature (168).jpg: NOT corrupted
# Mature (421).jpg: NOT corrupted
# Mature (1164).jpg: NOT corrupted
# Mature (108).jpg: NOT corrupted
# Mature (1229).jpg: NOT corrupted
# Mature (183).jpg: NOT corrupted
# Mature (1161).jpg: NOT corrupted
# Mature (308).jpg: NOT corrupted
# Mature (479).jpg: NOT corrupted
# Mature (1198).jpg: NOT corrupted
# Mature (1240).jpg: NOT corrupted
# Mature (1021).jpg: NOT corrupted
# Mature (259).jpg: NOT corrupted
# Mature (355).jpg: NOT corrupted
# Mature (391).jpg: NOT corrupted
# Mature (362).jpg: NOT corrupted
# Mature (356).jpg: NOT corrupted
# Mature (1228).jpg: NOT corrupted
# Mature (1253).jpg: NOT corrupted
# Mature (415).jpg: NOT corrupted
# Mature (203).jpg: NOT corrupted
# Mature (1171).jpg: NOT corrupted
# Mature (534).jpg: NOT corrupted
# Mature (401).jpg: NOT corrupted
# Mature (120).jpg: NOT corrupted
# Mature (1).jpg: NOT corrupted
# Mature (315).jpg: NOT corrupted
# Mature (464).jpg: NOT corrupted
# Mature (561).jpg: NOT corrupted
# Mature (145).jpg: NOT corrupted
# Mature (1243).jpg: NOT corrupted
# Mature (114).jpg: NOT corrupted
# Mature (554).jpg: NOT corrupted
# Mature (578).jpg: NOT corrupted
# Mature (1010).jpg: NOT corrupted
# Mature (250).jpg: NOT corrupted
# Mature (481).jpg: NOT corrupted
# Mature (564).jpg: NOT corrupted
# Mature (424).jpg: NOT corrupted
# Mature (457).jpg: NOT corrupted
# Mature (220).jpg: NOT corrupted
# Mature (287).jpg: NOT corrupted
# Mature (278).jpg: NOT corrupted
# Mature (520).jpg: NOT corrupted
# Mature (454).jpg: NOT corrupted
# Mature (146).jpg: NOT corrupted
# Mature (364).jpg: NOT corrupted
# Mature (175).jpg: NOT corrupted
# Mature (1068).jpg: NOT corrupted
# Mature (1187).jpg: NOT corrupted
# Mature (1196).jpg: NOT corrupted
# Mature (270).jpg: NOT corrupted
# Mature (1202).jpg: NOT corrupted
# Mature (543).jpg: NOT corrupted
# Mature (246).jpg: NOT corrupted
# Mature (282).jpg: NOT corrupted
# Mature (1082).jpg: NOT corrupted
# Mature (1183).jpg: NOT corrupted
# Mature (154).jpg: NOT corrupted
# Mature (1127).jpg: NOT corrupted
# Mature (444).jpg: NOT corrupted
# Mature (1139).jpg: NOT corrupted
# Mature (1115).jpg: NOT corrupted
# Mature (1098).jpg: NOT corrupted
# Mature (387).jpg: NOT corrupted
# Mature (371).jpg: NOT corrupted
# Mature (399).jpg: NOT corrupted
# Mature (529).jpg: NOT corrupted
# Mature (340).jpg: NOT corrupted
# Mature (276).jpg: NOT corrupted
# Mature (1267).jpg: NOT corrupted
# Mature (485).jpg: NOT corrupted
# Mature (205).jpg: NOT corrupted
# Mature (18).jpg: NOT corrupted
# Mature (190).jpg: NOT corrupted
# Mature (437).jpg: NOT corrupted
# Mature (449).jpg: NOT corrupted
# Mature (156).jpg: NOT corrupted
# Mature (1254).jpg: NOT corrupted
# Mature (137).jpg: NOT corrupted
# Mature (257).jpg: NOT corrupted
# Mature (545).jpg: NOT corrupted
# Mature (515).jpg: NOT corrupted
# Mature (23).jpg: NOT corrupted
# Mature (1248).jpg: NOT corrupted
# Mature (207).jpg: NOT corrupted
# Mature (251).jpg: NOT corrupted
# Mature (1062).jpg: NOT corrupted
# Mature (375).jpg: NOT corrupted
# Mature (1166).jpg: NOT corrupted
# Mature (384).jpg: NOT corrupted
# Mature (509).jpg: NOT corrupted
# Mature (1250).jpg: NOT corrupted
# Mature (394).jpg: NOT corrupted
# Mature (1245).jpg: NOT corrupted
# Mature (473).jpg: NOT corrupted
# Mature (440).jpg: NOT corrupted
# Mature (1189).jpg: NOT corrupted
# Mature (35).jpg: NOT corrupted
# Mature (41).jpg: NOT corrupted
# Mature (523).jpg: NOT corrupted
# Mature (317).jpg: NOT corrupted
# Mature (1020).jpg: NOT corrupted
# Mature (1199).jpg: NOT corrupted
# Mature (505).jpg: NOT corrupted
# Mature (552).jpg: NOT corrupted
# Mature (410).jpg: NOT corrupted
# Mature (565).jpg: NOT corrupted
# Mature (1084).jpg: NOT corrupted
# Mature (57).jpg: NOT corrupted
# Mature (1133).jpg: NOT corrupted
# Mature (472).jpg: NOT corrupted
# Mature (1086).jpg: NOT corrupted
# Mature (227).jpg: NOT corrupted
# Mature (514).jpg: NOT corrupted
# Mature (353).jpg: NOT corrupted
# Mature (1081).jpg: NOT corrupted
# Mature (1075).jpg: NOT corrupted
# Mature (469).jpg: NOT corrupted
# Mature (1220).jpg: NOT corrupted
# Mature (480).jpg: NOT corrupted
# Mature (1100).jpg: NOT corrupted
# Mature (1148).jpg: NOT corrupted
# Mature (1121).jpg: NOT corrupted
# Mature (51).jpg: NOT corrupted
# Mature (484).jpg: NOT corrupted
# Mature (555).jpg: NOT corrupted
# Mature (1217).jpg: NOT corrupted
# Mature (110).jpg: NOT corrupted
# Mature (1005).jpg: NOT corrupted
# Mature (1280).jpg: NOT corrupted
# Mature (221).jpg: NOT corrupted
# Mature (537).jpg: NOT corrupted
# Mature (1026).jpg: NOT corrupted
# Mature (1238).jpg: NOT corrupted
# Mature (1111).jpg: NOT corrupted
# Mature (360).jpg: NOT corrupted
# Mature (1023).jpg: NOT corrupted
# Mature (178).jpg: NOT corrupted
# Mature (351).jpg: NOT corrupted
# Mature (1176).jpg: NOT corrupted
# Mature (338).jpg: NOT corrupted
# Mature (470).jpg: NOT corrupted
# Mature (452).jpg: NOT corrupted
# Mature (1170).jpg: NOT corrupted
# Mature (24).jpg: NOT corrupted
# Mature (1145).jpg: NOT corrupted
# Mature (426).jpg: NOT corrupted
# Mature (385).jpg: NOT corrupted
# Mature (1244).jpg: NOT corrupted
# Mature (226).jpg: NOT corrupted
# Mature (30).jpg: NOT corrupted
# Mature (252).jpg: NOT corrupted
# Mature (405).jpg: NOT corrupted
# Mature (290).jpg: NOT corrupted
# Mature (1147).jpg: NOT corrupted
# Mature (173).jpg: NOT corrupted
# Mature (243).jpg: NOT corrupted
# Mature (33).jpg: NOT corrupted
# Mature (477).jpg: NOT corrupted
# Mature (1241).jpg: NOT corrupted
# Mature (517).jpg: NOT corrupted
# Mature (321).jpg: NOT corrupted
# Mature (525).jpg: NOT corrupted
# Mature (265).jpg: NOT corrupted
# Mature (403).jpg: NOT corrupted
# Mature (1044).jpg: NOT corrupted
# Mature (1266).jpg: NOT corrupted
# Mature (233).jpg: NOT corrupted
# Mature (316).jpg: NOT corrupted
# Mature (204).jpg: NOT corrupted
# Mature (194).jpg: NOT corrupted
# Mature (498).jpg: NOT corrupted
# Mature (1073).jpg: NOT corrupted
# Mature (1281).jpg: NOT corrupted
# Mature (296).jpg: NOT corrupted
# Mature (451).jpg: NOT corrupted
# Mature (1123).jpg: NOT corrupted
# Mature (134).jpg: NOT corrupted
# Mature (167).jpg: NOT corrupted
# Mature (432).jpg: NOT corrupted
# Mature (248).jpg: NOT corrupted
# Mature (213).jpg: NOT corrupted
# Mature (122).jpg: NOT corrupted
# Mature (1017).jpg: NOT corrupted
# Mature (483).jpg: NOT corrupted
# Mature (106).jpg: NOT corrupted
# Mature (302).jpg: NOT corrupted
# Mature (1132).jpg: NOT corrupted
# Mature (571).jpg: NOT corrupted
# Mature (1093).jpg: NOT corrupted
# Mature (263).jpg: NOT corrupted
# Mature (182).jpg: NOT corrupted
# Mature (1019).jpg: NOT corrupted
# Mature (189).jpg: NOT corrupted
# Mature (435).jpg: NOT corrupted
# Mature (125).jpg: NOT corrupted
# Mature (274).jpg: NOT corrupted
# Mature (127).jpg: NOT corrupted
# Mature (411).jpg: NOT corrupted
# Mature (216).jpg: NOT corrupted
# Mature (1178).jpg: NOT corrupted
# Mature (1156).jpg: NOT corrupted
# Mature (52).jpg: NOT corrupted
# Mature (1022).jpg: NOT corrupted
# Mature (1041).jpg: NOT corrupted
# Mature (443).jpg: NOT corrupted
# Mature (1129).jpg: NOT corrupted
# Mature (294).jpg: NOT corrupted
# Mature (312).jpg: NOT corrupted
# Mature (31).jpg: NOT corrupted
# Mature (126).jpg: NOT corrupted
# Mature (212).jpg: NOT corrupted
# Mature (1165).jpg: NOT corrupted
# Mature (398).jpg: NOT corrupted
# Mature (1212).jpg: NOT corrupted
# Mature (1027).jpg: NOT corrupted
# Mature (1096).jpg: NOT corrupted
# ...
# Mature (183).jpg: NOT corrupted
# Mature (260).jpg: NOT corrupted
# Mature (202).jpg: NOT corrupted
# Mature (155).jpg: NOT corrupted
# Mature (109).jpg: NOT corrupted
# Mature (96).jpg: NOT corrupted
# Mature (130).jpg: NOT corrupted
# Mature (80).jpg: NOT corrupted
# Mature (167).jpg: NOT corrupted
# Mature (292).jpg: NOT corrupted
# Mature (119).jpg: NOT corrupted
# Mature (203).jpg: NOT corrupted
# Mature (157).jpg: NOT corrupted
# Mature (149).jpg: NOT corrupted
# Mature (13).jpg: NOT corrupted
# Mature (131).jpg: NOT corrupted
# Mature (247).jpg: NOT corrupted
# Mature (81).jpg: NOT corrupted
# Mature (184).jpg: NOT corrupted
# Mature (262).jpg: NOT corrupted
# Mature (205).jpg: NOT corrupted
# Mature (169).jpg: NOT corrupted
# Mature (159).jpg: NOT corrupted
# Mature (150).jpg: NOT corrupted
# Mature (132).jpg: NOT corrupted
# Mature (188).jpg: NOT corrupted
# Mature (152).jpg: NOT corrupted
# Mature (133).jpg: NOT corrupted
# Mature (207).jpg: NOT corrupted
# Mature (154).jpg: NOT corrupted
# Mature (236).jpg: NOT corrupted
# Mature (160).jpg: NOT corrupted
# Mature (170).jpg: NOT corrupted
# Mature (271).jpg: NOT corrupted
# Mature (124).jpg: NOT corrupted
# Mature (38).jpg: NOT corrupted
# Mature (28).jpg: NOT corrupted
# Mature (294).jpg: NOT corrupted
# Mature (171).jpg: NOT corrupted
# Mature (208).jpg: NOT corrupted
# Mature (237).jpg: NOT corrupted
# Mature (120).jpg: NOT corrupted
# Mature (162).jpg: NOT corrupted
# Mature (220).jpg: NOT corrupted
# Mature (275).jpg: NOT corrupted
# Mature (263).jpg: NOT corrupted
# Mature (251).jpg: NOT corrupted
# Mature (175).jpg: NOT corrupted
# Mature (209).jpg: NOT corrupted
# Mature (238).jpg: NOT corrupted
# Mature (189).jpg: NOT corrupted
# Mature (221).jpg: NOT corrupted
# Mature (151).jpg: NOT corrupted
# Mature (61).jpg: NOT corrupted
# Mature (252).jpg: NOT corrupted
# Mature (177).jpg: NOT corrupted
# Mature (264).jpg: NOT corrupted
# Mature (51).jpg: NOT corrupted
# Mature (210).jpg: NOT corrupted
# Mature (191).jpg: NOT corrupted
# Mature (240).jpg: NOT corrupted
# Mature (290).jpg: NOT corrupted
# Mature (222).jpg: NOT corrupted
# Mature (30).jpg: NOT corrupted
# Mature (228).jpg: NOT corrupted
# Mature (40).jpg: NOT corrupted
# Mature (280).jpg: NOT corrupted
# Mature (284).jpg: NOT corrupted
# Mature (192).jpg: NOT corrupted
# Mature (241).jpg: NOT corrupted
# Mature (213).jpg: NOT corrupted
# Mature (293).jpg: NOT corrupted
# Mature (223).jpg: NOT corrupted
# Mature (253).jpg: NOT corrupted
# Mature (265).jpg: NOT corrupted
# Mature (215).jpg: NOT corrupted
# Mature (310).jpg: NOT corrupted
# Mature (303).jpg: NOT corrupted
# Mature (224).jpg: NOT corrupted
# Mature (214).jpg: NOT corrupted
# Mature (295).jpg: NOT corrupted
# Mature (211).jpg: NOT corrupted
# Mature (227).jpg: NOT corrupted
# Mature (266).jpg: NOT corrupted
# Mature (216).jpg: NOT corrupted
# Mature (21).jpg: NOT corrupted
# Mature (11).jpg: NOT corrupted
# Mature (296).jpg: NOT corrupted
# Mature (226).jpg: NOT corrupted
# Mature (279).jpg: NOT corrupted
# Mature (281).jpg: NOT corrupted
# Mature (42).jpg: NOT corrupted
# Mature (218).jpg: NOT corrupted
# Mature (254).jpg: NOT corrupted
# Mature (242).jpg: NOT corrupted
# Mature (319).jpg: NOT corrupted
# Mature (311).jpg: NOT corrupted
# Mature (306).jpg: NOT corrupted
# Mature (256).jpg: NOT corrupted
# Mature (297).jpg: NOT corrupted
# Mature (267).jpg: NOT corrupted
# Mature (89).jpg: NOT corrupted
# Mature (232).jpg: NOT corrupted
# Mature (219).jpg: NOT corrupted
# Mature (88).jpg: NOT corrupted
# Mature (230).jpg: NOT corrupted
# Mature (282).jpg: NOT corrupted
# Mature (318).jpg: NOT corrupted
# Mature (43).jpg: NOT corrupted
# Mature (320).jpg: NOT corrupted
# Mature (3).jpg: NOT corrupted
# Mature (312).jpg: NOT corrupted
# Mature (255).jpg: NOT corrupted
# Mature (298).jpg: NOT corrupted
# Mature (283).jpg: NOT corrupted
# Mature (194).jpg: NOT corrupted
# Mature (82).jpg: NOT corrupted
# Mature (268).jpg: NOT corrupted
# Mature (231).jpg: NOT corrupted
# Mature (244).jpg: NOT corrupted
# Mature (33).jpg: NOT corrupted
# Mature (299).jpg: NOT corrupted
# Mature (285).jpg: NOT corrupted
# Mature (313).jpg: NOT corrupted
# Mature (257).jpg: NOT corrupted
# Mature (269).jpg: NOT corrupted
# Mature (234).jpg: NOT corrupted
# Mature (204).jpg: NOT corrupted
# Mature (321).jpg: NOT corrupted
# Mature (300).jpg: NOT corrupted
# Mature (23).jpg: NOT corrupted
# Mature (258).jpg: NOT corrupted
# Mature (273).jpg: NOT corrupted
# Mature (233).jpg: NOT corrupted
# Mature (235).jpg: NOT corrupted
# Mature (286).jpg: NOT corrupted
# Mature (301).jpg: NOT corrupted
# Mature (245).jpg: NOT corrupted
# Mature (201).jpg: NOT corrupted
# Mature (206).jpg: NOT corrupted
# Mature (274).jpg: NOT corrupted
# Mature (314).jpg: NOT corrupted
# Mature (225).jpg: NOT corrupted
# Mature (272).jpg: NOT corrupted
# Mature (49).jpg: NOT corrupted
# Mature (259).jpg: NOT corrupted
# Mature (193).jpg: NOT corrupted
# Mature (287).jpg: NOT corrupted
# Mature (315).jpg: NOT corrupted
# Mature (307).jpg: NOT corrupted
# Mature (302).jpg: NOT corrupted
# Mature (246).jpg: NOT corrupted
# Mature (277).jpg: NOT corrupted
# Mature (72).jpg: NOT corrupted
# Mature (261).jpg: NOT corrupted
# Mature (75).jpg: NOT corrupted
# Mature (304).jpg: NOT corrupted
# Mature (9).jpg: NOT corrupted
# Mature (249).jpg: NOT corrupted
# Mature (308).jpg: NOT corrupted
# Mature (316).jpg: NOT corrupted
# Mature (305).jpg: NOT corrupted
# Mature (309).jpg: NOT corrupted
# Mature (288).jpg: NOT corrupted
# Mature (270).jpg: NOT corrupted
# Mature (317).jpg: NOT corrupted
# /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/valid/Normal
# Checking images in directory: /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/valid/Normal
# Normal (1).jpg: NOT corrupted
# Normal (124).jpg: NOT corrupted
# Normal (131).jpg: NOT corrupted
# Normal (145).jpg: NOT corrupted
# Normal (160).jpg: NOT corrupted
# Normal (162).jpg: NOT corrupted
# Normal (165).jpg: NOT corrupted
# Normal (178).jpg: NOT corrupted
# Normal (183).jpg: NOT corrupted
# Normal (186).jpg: NOT corrupted
# Normal (188).jpg: NOT corrupted
# Normal (200).jpg: NOT corrupted
# Normal (202).jpg: NOT corrupted
# Normal (25).jpg: NOT corrupted
# Normal (26).jpg: NOT corrupted
# Normal (14).jpg: NOT corrupted
# Normal (27).jpg: NOT corrupted
# Normal (28).jpg: NOT corrupted
# Normal (15).jpg: NOT corrupted
# Normal (16).jpg: NOT corrupted
# Normal (32).jpg: NOT corrupted
# Normal (17).jpg: NOT corrupted
# Normal (33).jpg: NOT corrupted
# Normal (2).jpg: NOT corrupted
# Normal (18).jpg: NOT corrupted
# Normal (3).jpg: NOT corrupted
# Normal (34).jpg: NOT corrupted
# Normal (19).jpg: NOT corrupted
# Normal (6).jpg: NOT corrupted
# Normal (35).jpg: NOT corrupted
# Normal (20).jpg: NOT corrupted
# Normal (36).jpg: NOT corrupted
# Normal (8).jpg: NOT corrupted
# Normal (84).jpg: NOT corrupted
# Normal (21).jpg: NOT corrupted
# Normal (9).jpg: NOT corrupted
# Normal (116).jpg: NOT corrupted
# Normal (37).jpg: NOT corrupted
# Normal (85).jpg: NOT corrupted
# Normal (22).jpg: NOT corrupted
# Normal (54).jpg: NOT corrupted
# Normal (68).jpg: NOT corrupted
# Normal (38).jpg: NOT corrupted
# Normal (118).jpg: NOT corrupted
# Normal (12).jpg: NOT corrupted
# Normal (86).jpg: NOT corrupted
# Normal (23).jpg: NOT corrupted
# Normal (69).jpg: NOT corrupted
# Normal (99).jpg: NOT corrupted
# Normal (55).jpg: NOT corrupted
# Normal (13).jpg: NOT corrupted
# Normal (119).jpg: NOT corrupted
# Normal (263).jpg: NOT corrupted
# Normal (39).jpg: NOT corrupted
# Normal (87).jpg: NOT corrupted
# Normal (70).jpg: NOT corrupted
# Normal (57).jpg: NOT corrupted
# Normal (120).jpg: NOT corrupted
# Normal (141).jpg: NOT corrupted
# Normal (24).jpg: NOT corrupted
# Normal (158).jpg: NOT corrupted
# Normal (89).jpg: NOT corrupted
# Normal (41).jpg: NOT corrupted
# Normal (45).jpg: NOT corrupted
# Normal (102).jpg: NOT corrupted
# Normal (121).jpg: NOT corrupted
# Normal (142).jpg: NOT corrupted
# Normal (58).jpg: NOT corrupted
# Normal (159).jpg: NOT corrupted
# Normal (71).jpg: NOT corrupted
# Normal (49).jpg: NOT corrupted
# Normal (46).jpg: NOT corrupted
# Normal (103).jpg: NOT corrupted
# Normal (123).jpg: NOT corrupted
# Normal (90).jpg: NOT corrupted
# Normal (72).jpg: NOT corrupted
# Normal (50).jpg: NOT corrupted
# Normal (135).jpg: NOT corrupted
# Normal (161).jpg: NOT corrupted
# Normal (104).jpg: NOT corrupted
# Normal (176).jpg: NOT corrupted
# Normal (44).jpg: NOT corrupted
# Normal (59).jpg: NOT corrupted
# Normal (74).jpg: NOT corrupted
# Normal (143).jpg: NOT corrupted
# Normal (126).jpg: NOT corrupted
# Normal (163).jpg: NOT corrupted
# Normal (51).jpg: NOT corrupted
# Normal (48).jpg: NOT corrupted
# Normal (91).jpg: NOT corrupted
# Normal (105).jpg: NOT corrupted
# Normal (60).jpg: NOT corrupted
# Normal (177).jpg: NOT corrupted
# Normal (75).jpg: NOT corrupted
# Normal (127).jpg: NOT corrupted
# Normal (164).jpg: NOT corrupted
# Normal (61).jpg: NOT corrupted
# Normal (179).jpg: NOT corrupted
# Normal (92).jpg: NOT corrupted
# Normal (106).jpg: NOT corrupted
# Normal (52).jpg: NOT corrupted
# Normal (76).jpg: NOT corrupted
# Normal (207).jpg: NOT corrupted
# Normal (166).jpg: NOT corrupted
# Normal (63).jpg: NOT corrupted
# Normal (128).jpg: NOT corrupted
# Normal (180).jpg: NOT corrupted
# Normal (107).jpg: NOT corrupted
# Normal (144).jpg: NOT corrupted
# Normal (208).jpg: NOT corrupted
# Normal (93).jpg: NOT corrupted
# Normal (108).jpg: NOT corrupted
# Normal (129).jpg: NOT corrupted
# Normal (290).jpg: NOT corrupted
# Normal (209).jpg: NOT corrupted
# Normal (146).jpg: NOT corrupted
# Normal (181).jpg: NOT corrupted
# Normal (94).jpg: NOT corrupted
# Normal (193).jpg: NOT corrupted
# Normal (77).jpg: NOT corrupted
# Normal (64).jpg: NOT corrupted
# Normal (109).jpg: NOT corrupted
# Normal (5).jpg: NOT corrupted
# Normal (147).jpg: NOT corrupted
# Normal (95).jpg: NOT corrupted
# Normal (167).jpg: NOT corrupted
# Normal (130).jpg: NOT corrupted
# Normal (182).jpg: NOT corrupted
# Normal (78).jpg: NOT corrupted
# Normal (194).jpg: NOT corrupted
# Normal (148).jpg: NOT corrupted
# Normal (65).jpg: NOT corrupted
# Normal (168).jpg: NOT corrupted
# Normal (132).jpg: NOT corrupted
# Normal (96).jpg: NOT corrupted
# Normal (110).jpg: NOT corrupted
# Normal (184).jpg: NOT corrupted
# Normal (80).jpg: NOT corrupted
# Normal (318).jpg: NOT corrupted
# Normal (66).jpg: NOT corrupted
# Normal (149).jpg: NOT corrupted
# Normal (212).jpg: NOT corrupted
# Normal (134).jpg: NOT corrupted
# Normal (169).jpg: NOT corrupted
# Normal (97).jpg: NOT corrupted
# Normal (112).jpg: NOT corrupted
# Normal (81).jpg: NOT corrupted
# Normal (185).jpg: NOT corrupted
# Normal (195).jpg: NOT corrupted
# Normal (136).jpg: NOT corrupted
# Normal (273).jpg: NOT corrupted
# Normal (137).jpg: NOT corrupted
# Normal (213).jpg: NOT corrupted
# Normal (187).jpg: NOT corrupted
# Normal (98).jpg: NOT corrupted
# Normal (170).jpg: NOT corrupted
# Normal (113).jpg: NOT corrupted
# Normal (83).jpg: NOT corrupted
# Normal (196).jpg: NOT corrupted
# Normal (150).jpg: NOT corrupted
# Normal (247).jpg: NOT corrupted
# Normal (171).jpg: NOT corrupted
# Normal (197).jpg: NOT corrupted
# Normal (189).jpg: NOT corrupted
# Normal (224).jpg: NOT corrupted
# Normal (138).jpg: NOT corrupted
# Normal (214).jpg: NOT corrupted
# Normal (115).jpg: NOT corrupted
# Normal (154).jpg: NOT corrupted
# Normal (250).jpg: NOT corrupted
# Normal (198).jpg: NOT corrupted
# Normal (190).jpg: NOT corrupted
# Normal (173).jpg: NOT corrupted
# Normal (218).jpg: NOT corrupted
# Normal (53).jpg: NOT corrupted
# Normal (139).jpg: NOT corrupted
# Normal (251).jpg: NOT corrupted
# Normal (155).jpg: NOT corrupted
# Normal (156).jpg: NOT corrupted
# Normal (174).jpg: NOT corrupted
# Normal (151).jpg: NOT corrupted
# Normal (140).jpg: NOT corrupted
# Normal (219).jpg: NOT corrupted
# Normal (264).jpg: NOT corrupted
# Normal (191).jpg: NOT corrupted
# Normal (252).jpg: NOT corrupted
# Normal (157).jpg: NOT corrupted
# Normal (152).jpg: NOT corrupted
# Normal (79).jpg: NOT corrupted
# Normal (7).jpg: NOT corrupted
# Normal (299).jpg: NOT corrupted
# Normal (235).jpg: NOT corrupted
# Normal (192).jpg: NOT corrupted
# Normal (199).jpg: NOT corrupted
# Normal (220).jpg: NOT corrupted
# Normal (253).jpg: NOT corrupted
# Normal (153).jpg: NOT corrupted
# Normal (266).jpg: NOT corrupted
# Normal (274).jpg: NOT corrupted
# Normal (205).jpg: NOT corrupted
# Normal (242).jpg: NOT corrupted
# Normal (236).jpg: NOT corrupted
# Normal (201).jpg: NOT corrupted
# Normal (73).jpg: NOT corrupted
# Normal (254).jpg: NOT corrupted
# Normal (222).jpg: NOT corrupted
# Normal (175).jpg: NOT corrupted
# Normal (206).jpg: NOT corrupted
# Normal (294).jpg: NOT corrupted
# Normal (267).jpg: NOT corrupted
# Normal (62).jpg: NOT corrupted
# Normal (237).jpg: NOT corrupted
# Normal (203).jpg: NOT corrupted
# Normal (255).jpg: NOT corrupted
# Normal (284).jpg: NOT corrupted
# Normal (223).jpg: NOT corrupted
# Normal (315).jpg: NOT corrupted
# Normal (204).jpg: NOT corrupted
# Normal (238).jpg: NOT corrupted
# Normal (31).jpg: NOT corrupted
# Normal (306).jpg: NOT corrupted
# Normal (276).jpg: NOT corrupted
# Normal (233).jpg: NOT corrupted
# Normal (256).jpg: NOT corrupted
# Normal (56).jpg: NOT corrupted
# Normal (225).jpg: NOT corrupted
# Normal (248).jpg: NOT corrupted
# Normal (240).jpg: NOT corrupted
# Normal (229).jpg: NOT corrupted
# Normal (47).jpg: NOT corrupted
# Normal (295).jpg: NOT corrupted
# Normal (277).jpg: NOT corrupted
# Normal (268).jpg: NOT corrupted
# Normal (257).jpg: NOT corrupted
# Normal (285).jpg: NOT corrupted
# Normal (226).jpg: NOT corrupted
# Normal (316).jpg: NOT corrupted
# Normal (241).jpg: NOT corrupted
# Normal (307).jpg: NOT corrupted
# Normal (231).jpg: NOT corrupted
# Normal (296).jpg: NOT corrupted
# Normal (227).jpg: NOT corrupted
# Normal (40).jpg: NOT corrupted
# Normal (232).jpg: NOT corrupted
# Normal (243).jpg: NOT corrupted
# Normal (286).jpg: NOT corrupted
# Normal (217).jpg: NOT corrupted
# Normal (258).jpg: NOT corrupted
# Normal (101).jpg: NOT corrupted
# Normal (279).jpg: NOT corrupted
# Normal (317).jpg: NOT corrupted
# Normal (234).jpg: NOT corrupted
# Normal (244).jpg: NOT corrupted
# Normal (10).jpg: NOT corrupted
# Normal (269).jpg: NOT corrupted
# Normal (280).jpg: NOT corrupted
# Normal (297).jpg: NOT corrupted
# Normal (259).jpg: NOT corrupted
# Normal (308).jpg: NOT corrupted
# Normal (287).jpg: NOT corrupted
# Normal (245).jpg: NOT corrupted
# Normal (319).jpg: NOT corrupted
# Normal (82).jpg: NOT corrupted
# Normal (230).jpg: NOT corrupted
# Normal (275).jpg: NOT corrupted
# Normal (260).jpg: NOT corrupted
# Normal (11).jpg: NOT corrupted
# Normal (88).jpg: NOT corrupted
# Normal (327).jpg: NOT corrupted
# Normal (111).jpg: NOT corrupted
# Normal (281).jpg: NOT corrupted
# Normal (210).jpg: NOT corrupted
# Normal (133).jpg: NOT corrupted
# Normal (298).jpg: NOT corrupted
# Normal (261).jpg: NOT corrupted
# Normal (288).jpg: NOT corrupted
# Normal (228).jpg: NOT corrupted
# Normal (270).jpg: NOT corrupted
# Normal (325).jpg: NOT corrupted
# Normal (172).jpg: NOT corrupted
# Normal (320).jpg: NOT corrupted
# Normal (309).jpg: NOT corrupted
# Normal (246).jpg: NOT corrupted
# Normal (300).jpg: NOT corrupted
# Normal (249).jpg: NOT corrupted
# Normal (328).jpg: NOT corrupted
# Normal (289).jpg: NOT corrupted
# Normal (221).jpg: NOT corrupted
# Normal (100).jpg: NOT corrupted
# Normal (114).jpg: NOT corrupted
# Normal (282).jpg: NOT corrupted
# Normal (304).jpg: NOT corrupted
# Normal (262).jpg: NOT corrupted
# Normal (271).jpg: NOT corrupted
# Normal (122).jpg: NOT corrupted
# Normal (29).jpg: NOT corrupted
# Normal (301).jpg: NOT corrupted
# Normal (4).jpg: NOT corrupted
# Normal (310).jpg: NOT corrupted
# Normal (321).jpg: NOT corrupted
# Normal (330).jpg: NOT corrupted
# Normal (291).jpg: NOT corrupted
# Normal (292).jpg: NOT corrupted
# Normal (311).jpg: NOT corrupted
# Normal (265).jpg: NOT corrupted
# Normal (272).jpg: NOT corrupted
# Normal (302).jpg: NOT corrupted
# Normal (293).jpg: NOT corrupted
# Normal (30).jpg: NOT corrupted
# Normal (322).jpg: NOT corrupted
# Normal (43).jpg: NOT corrupted
# Normal (67).jpg: NOT corrupted
# Normal (211).jpg: NOT corrupted
# Normal (283).jpg: NOT corrupted
# Normal (303).jpg: NOT corrupted
# Normal (314).jpg: NOT corrupted
# Normal (323).jpg: NOT corrupted
# Normal (331).jpg: NOT corrupted
# Normal (312).jpg: NOT corrupted
# Normal (305).jpg: NOT corrupted
# Normal (42).jpg: NOT corrupted
# Normal (117).jpg: NOT corrupted
# Normal (215).jpg: NOT corrupted
# Normal (125).jpg: NOT corrupted
# Normal (329).jpg: NOT corrupted
# Normal (278).jpg: NOT corrupted
# Normal (324).jpg: NOT corrupted
# Normal (313).jpg: NOT corrupted
# Normal (332).jpg: NOT corrupted
# Normal (239).jpg: NOT corrupted
# Normal (216).jpg: NOT corrupted
# Normal (326).jpg: NOT corrupted

# %% [markdown]
# # **2. Consistent Structure**
#
# •	  Folder names match class labels exactly (immature, mature, normal).
#
# •	  No extra or misplaced files (e.g., .txt, .DS_Store, etc.).
#
# •	  Each folder contains only images of that class.

# %%
import os

def check_folder_names(base_directory, expected_folders):
    """
    Checks if the folders in a base directory match the expected list of folder names.

    Args:
        base_directory (str): The path to the base directory.
        expected_folders (list): A list of expected folder names.
    """
    print(f"Checking folder names in base directory: {base_directory}")

    if not os.path.isdir(base_directory):
        print(f"Error: Base directory not found at {base_directory}")
        return

    found_folders = set([item for item in os.listdir(base_directory) if os.path.isdir(os.path.join(base_directory, item))])
    expected_folders_set = set(expected_folders)

    missing_folders = expected_folders_set - found_folders
    if missing_folders:
        print("Warning: Expected folders not found:")
        for folder in missing_folders:
            print(f"- {folder}")

    unexpected_folders = found_folders - expected_folders_set
    if unexpected_folders:
        print("Warning: Unexpected folders found:")
        for folder in unexpected_folders:
            print(f"- {folder}")

    if not missing_folders and not unexpected_folders:
        print("All expected folders found and no unexpected folders.")


def check_image_files_only(directory):
    """
    Checks if a directory contains only image files (based on common extensions).

    Args:
        directory (str): The path to the directory to check.
    """
    print(f"Checking files in directory: {directory}")

    if not os.path.isdir(directory):
        print(f"Error: Directory not found at {directory}")
        return

    non_image_files_found = False
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)
        if os.path.isfile(filepath):
            # Check if the file is an image (basic check based on extension)
            if not filename.lower().endswith(('.png', '.jpg', '.jpeg')):
                print(f"Warning: Non-image file found: {filename}")
                non_image_files_found = True
        else:
            print(f"Info: Non-file item found (skipping): {filename}")

    if not non_image_files_found:
        print("All files appear to be images.")

# Example usage (using variables from your notebook):
# address='/content/drive/My Drive/PROJECT1/data/data_set(15,15,70)'
# class_es=['test','train','valid']
# sub_class_es=['Immature','Mature','Normal']

# Check the main class folders:
#

# Check the sub-class folders within each class folder:
#

# Check the files within each sub-class folder:
#

# %%
check_folder_names(address, class_es)
# Out:
# Checking folder names in base directory: /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)
# All expected folders found and no unexpected folders.

# %%
for cls in class_es:
     check_folder_names(os.path.join(address, cls), sub_class_es)
# Out:
# Checking folder names in base directory: /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/test
# All expected folders found and no unexpected folders.
# Checking folder names in base directory: /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/train
# All expected folders found and no unexpected folders.
# Checking folder names in base directory: /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/valid
# All expected folders found and no unexpected folders.

# %%
for cls in class_es:
     for sub_cls in sub_class_es:
         check_image_files_only(os.path.join(address, cls, sub_cls))
# Out:
# Checking files in directory: /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/test/Immature
# All files appear to be images.
# Checking files in directory: /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/test/Mature
# All files appear to be images.
# Checking files in directory: /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/test/Normal
# All files appear to be images.
# Checking files in directory: /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/train/Immature
# All files appear to be images.
# Checking files in directory: /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/train/Mature
# All files appear to be images.
# Checking files in directory: /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/train/Normal
# All files appear to be images.
# Checking files in directory: /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/valid/Immature
# All files appear to be images.
# Checking files in directory: /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/valid/Mature
# All files appear to be images.
# Checking files in directory: /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/valid/Normal
# All files appear to be images.

# %%
import os

def check_filename_label_accuracy(base_directory, class_es, sub_class_es):
       print(f"Checking filename label accuracy in base directory: {base_directory}")
    if not os.path.isdir(base_directory):
        print(f"Error: Base directory not found at {base_directory}")
        return
    for cls in class_es:
        class_folder_path = os.path.join(base_directory, cls)
        if not os.path.isdir(class_folder_path):
            print(f"Warning: Class folder not found (skipping): {class_folder_path}")
            continue
        for sub_cls in sub_class_es:
            sub_class_folder_path = os.path.join(class_folder_path, sub_cls)
            print(f"\nChecking folder: {sub_class_folder_path}")
            if not os.path.isdir(sub_class_folder_path):
                print(f"Warning: Sub-class folder not found (skipping): {sub_class_folder_path}")
                continue
            for filename in os.listdir(sub_class_folder_path):
                filepath = os.path.join(sub_class_folder_path, filename)
                if os.path.isfile(filepath):
                    # Get the folder name (sub_cls) and check if it's in the filename (case-insensitive)
                    if sub_cls.lower() not in filename.lower():
                        print(f"Warning: Filename '{filename}' in folder '{sub_cls}' does not contain the folder name.")
                    else:
                        print(f"Filename '{filename}' in folder '{sub_cls}' contains the folder name.")
                else:
                    print(f"Info: Non-file item found (skipping): {filename}")
# Example usage (using variables from your notebook):
# address='/content/drive/My Drive/PROJECT1/data/data_set(15,15,70)'
# class_es=['test','train','valid']
# sub_class_es=['Immature','Mature','Normal']

# %%
 check_filename_label_accuracy(address, class_es, sub_class_es)
# Out:
# Streaming output truncated to the last 5000 lines.
# Filename 'Immature (492).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (493).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (494).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (495).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (496).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (497).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (498).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (499).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (500).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (501).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (502).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (503).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (504).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (505).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (506).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (507).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (508).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (509).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (510).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (511).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (512).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (513).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (514).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (515).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (516).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (517).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (518).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (519).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (520).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (521).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (522).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (523).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (524).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (525).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (526).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (527).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (528).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (529).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (530).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (531).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (532).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (533).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (534).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (535).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (536).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (537).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (538).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (539).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (540).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (541).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (542).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (543).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (544).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (545).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (546).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (547).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (548).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (549).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (550).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (551).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (552).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (553).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (554).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (555).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (556).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (557).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (558).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (559).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (560).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (561).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (562).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (563).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (564).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (565).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (566).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (567).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (568).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (569).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (570).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (571).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (572).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (573).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (574).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (575).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (576).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (577).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (578).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (579).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (580).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (581).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (582).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (583).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (584).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (585).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (586).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (587).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (588).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (589).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (590).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (591).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (592).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (593).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (594).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (595).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (596).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (597).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (598).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (599).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (600).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (601).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (602).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (603).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (604).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (605).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (606).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (607).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (608).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (609).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (610).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (611).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (612).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (613).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (614).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (615).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (616).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (617).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (618).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (619).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (620).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (621).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (622).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (623).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (624).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (625).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (626).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (627).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (628).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (629).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (630).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (631).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (632).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (633).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (634).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (635).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (636).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (637).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (638).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (639).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (640).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (641).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (642).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (643).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (644).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (645).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (646).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (647).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (648).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (649).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (650).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (651).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (652).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (653).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (654).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (655).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (656).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (657).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (658).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (659).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (660).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (661).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (662).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (663).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (664).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (665).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (666).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (667).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (668).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (669).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (670).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (671).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (672).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (673).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (674).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (675).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (676).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (677).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (678).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (679).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (680).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (681).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (682).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (683).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (684).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (685).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (686).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (687).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (688).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (689).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (690).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (691).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (692).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (693).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (694).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (695).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (696).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (697).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (698).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (699).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (700).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (701).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (702).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (703).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (704).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (705).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (706).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (707).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (708).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (709).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (710).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (711).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (712).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (713).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (714).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (715).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (716).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (717).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (718).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (719).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (720).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (721).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (722).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (723).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (724).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (725).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (726).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (727).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (728).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (729).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (730).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (731).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (732).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (733).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (734).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (735).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (736).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (737).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (738).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (739).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (740).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (741).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (742).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (743).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (744).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (745).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (746).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (747).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (748).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (749).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (750).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (751).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (752).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (753).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (754).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (755).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (756).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (757).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (758).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (759).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (760).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (761).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (762).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (763).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (764).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (765).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (766).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (767).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (768).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (769).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (770).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (771).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (772).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (773).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (774).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (775).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (776).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (777).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (778).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (779).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (780).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (781).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (782).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (783).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (784).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (785).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (786).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (787).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (788).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (789).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (790).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (791).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (792).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (793).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (794).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (795).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (796).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (797).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (798).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (799).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (800).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (801).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (802).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (803).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (804).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (805).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (806).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (807).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (808).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (809).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (810).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (811).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (812).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (813).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (814).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (815).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (816).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (817).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (818).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (819).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (820).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (821).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (822).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (823).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (824).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (825).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (826).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (827).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (828).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (829).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (830).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (831).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (832).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (833).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (834).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (835).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (836).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (837).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (838).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (839).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (840).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (841).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (842).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (843).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (844).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (845).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (846).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (847).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (848).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (849).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (850).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (851).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (852).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (853).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (854).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (855).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (856).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (857).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (858).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (859).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (860).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (861).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (862).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (863).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (864).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (865).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (866).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (867).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (868).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (869).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (870).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (871).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (872).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (873).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (874).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (875).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (876).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (877).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (878).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (879).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (880).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (881).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (882).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (883).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (884).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (885).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (886).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (887).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (888).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (889).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (890).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (891).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (892).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (893).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (894).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (895).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (896).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (897).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (898).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (899).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (900).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (901).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (902).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (903).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (904).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (905).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (906).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (907).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (908).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (909).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (910).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (911).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (912).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (913).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (914).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (915).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (916).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (917).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (918).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (919).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (920).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (921).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (922).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (923).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (924).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (925).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (926).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (927).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (928).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (929).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (930).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (931).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (932).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (933).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (934).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (935).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (936).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (937).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (938).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (939).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (940).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (941).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (942).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (943).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (944).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (945).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (946).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (947).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (948).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (949).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (950).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (951).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (952).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (953).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (954).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (955).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (956).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (957).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (958).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (959).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (960).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (961).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (962).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (963).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (964).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (965).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (966).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (967).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (968).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (969).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (970).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (971).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (972).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (973).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (974).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (975).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (976).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (977).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (978).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (979).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (980).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (981).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (982).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (983).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (984).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (985).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (986).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (987).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (988).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (989).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (990).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (991).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (992).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (993).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (994).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (995).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (996).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (997).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (998).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (999).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1000).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1001).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1002).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1003).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1004).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1005).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1006).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1007).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1008).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1009).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1010).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1011).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1012).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1013).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1014).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1015).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1016).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1017).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1018).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1019).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1020).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1021).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1022).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1023).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1024).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1025).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1026).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1027).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1028).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1029).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1030).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1031).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1032).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1033).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1034).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1035).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1036).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1037).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1038).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1039).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1040).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1041).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1042).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1043).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1044).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1045).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1046).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1047).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1048).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1049).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1050).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1051).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1052).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1053).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1054).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1055).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1056).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1057).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1058).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1059).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1060).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1061).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1062).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1063).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1064).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1065).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1066).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1067).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1068).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1069).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1070).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1071).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1072).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1073).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1074).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1075).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1076).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1077).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1078).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1079).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1080).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1081).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1082).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1083).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1084).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1085).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1086).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1087).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1088).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1089).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1090).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1091).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1092).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1093).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1094).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1095).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1096).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1097).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1098).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1099).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1100).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1101).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1102).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1103).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1104).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1105).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1106).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1107).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1108).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1109).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1110).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1111).jpg' in folder 'Immature' contains the folder name.
# Filename 'Immature (1112).jpg' in folder 'Immature' contains the folder name.
# ...
# Filename 'Normal (290).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (209).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (146).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (181).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (94).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (193).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (77).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (64).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (109).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (5).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (147).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (95).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (167).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (130).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (182).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (78).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (194).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (148).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (65).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (168).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (132).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (96).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (110).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (184).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (80).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (318).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (66).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (149).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (212).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (134).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (169).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (97).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (112).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (81).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (185).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (195).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (136).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (273).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (137).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (213).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (187).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (98).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (170).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (113).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (83).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (196).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (150).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (247).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (171).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (197).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (189).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (224).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (138).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (214).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (115).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (154).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (250).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (198).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (190).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (173).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (218).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (53).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (139).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (251).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (155).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (156).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (174).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (151).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (140).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (219).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (264).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (191).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (252).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (157).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (152).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (79).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (7).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (299).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (235).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (192).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (199).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (220).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (253).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (153).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (266).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (274).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (205).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (242).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (236).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (201).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (73).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (254).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (222).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (175).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (206).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (294).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (267).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (62).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (237).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (203).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (255).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (284).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (223).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (315).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (204).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (238).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (31).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (306).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (276).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (233).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (256).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (56).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (225).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (248).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (240).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (229).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (47).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (295).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (277).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (268).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (257).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (285).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (226).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (316).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (241).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (307).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (231).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (296).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (227).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (40).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (232).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (243).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (286).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (217).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (258).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (101).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (279).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (317).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (234).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (244).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (10).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (269).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (280).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (297).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (259).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (308).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (287).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (245).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (319).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (82).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (230).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (275).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (260).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (11).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (88).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (327).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (111).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (281).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (210).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (133).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (298).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (261).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (288).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (228).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (270).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (325).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (172).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (320).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (309).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (246).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (300).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (249).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (328).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (289).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (221).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (100).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (114).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (282).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (304).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (262).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (271).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (122).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (29).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (301).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (4).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (310).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (321).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (330).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (291).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (292).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (311).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (265).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (272).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (302).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (293).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (30).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (322).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (43).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (67).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (211).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (283).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (303).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (314).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (323).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (331).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (312).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (305).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (42).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (117).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (215).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (125).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (329).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (278).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (324).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (313).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (332).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (239).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (216).jpg' in folder 'Normal' contains the folder name.
# Filename 'Normal (326).jpg' in folder 'Normal' contains the folder name.

# %%
def check_image_size_consistency(directory, expected_size):
    print(f"Checking image sizes in directory: {directory}")

    if not os.path.isdir(directory):
        print(f"Error: Directory not found at {directory}")
        return

    size_mismatch_found = False
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)
        if os.path.isfile(filepath):
            try:
                img = Image.open(filepath)
                if img.size != expected_size:
                    print(f"Warning: Image '{filename}' has size {img.size}, expected {expected_size}.")
                    size_mismatch_found = True
            except IOError:
                print(f"Error: Could not open or process image file: {filename}")
                size_mismatch_found = True # Consider inability to open as a mismatch for the success message
        else:
            print(f"Info: Non-file item found (skipping): {filename}")


    if not size_mismatch_found:
        print(f"All images in directory '{directory}' are of expected size {expected_size}.")


# Checking for pixel value normalization (e.g., divided by 255) is more complex
# and typically done during the data loading and preprocessing steps for model training.
# It's not something easily checked by just looking at the image files themselves
# without knowing the original pixel range.

# %%
expected_image_size = (224, 224)

# %%
for cls in class_es:
  for sub_cls in sub_class_es:
    check_image_size_consistency(os.path.join(address, cls, sub_cls), expected_image_size)
# Out:
# Checking image sizes in directory: /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/test/Immature
# All images in directory '/content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/test/Immature' are of expected size (224, 224).
# Checking image sizes in directory: /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/test/Mature
# All images in directory '/content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/test/Mature' are of expected size (224, 224).
# Checking image sizes in directory: /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/test/Normal
# All images in directory '/content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/test/Normal' are of expected size (224, 224).
# Checking image sizes in directory: /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/train/Immature
# All images in directory '/content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/train/Immature' are of expected size (224, 224).
# Checking image sizes in directory: /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/train/Mature
# All images in directory '/content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/train/Mature' are of expected size (224, 224).
# Checking image sizes in directory: /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/train/Normal
# All images in directory '/content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/train/Normal' are of expected size (224, 224).
# Checking image sizes in directory: /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/valid/Immature
# All images in directory '/content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/valid/Immature' are of expected size (224, 224).
# Checking image sizes in directory: /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/valid/Mature
# All images in directory '/content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/valid/Mature' are of expected size (224, 224).
# Checking image sizes in directory: /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/valid/Normal
# All images in directory '/content/drive/My Drive/PROJECT1/data/data_set(15,15,70)/valid/Normal' are of expected size (224, 224).

# %%
import os
import pandas as pd

def check_class_distribution(base_directory, class_es, sub_class_es):
    print(f"Checking class distribution in base directory: {base_directory}")
    if not os.path.isdir(base_directory):
        print(f"Error: Base directory not found at {base_directory}")
        return
    distribution_data = {}
    total_images = 0
    for cls in class_es:
        class_folder_path = os.path.join(base_directory, cls)
        if not os.path.isdir(class_folder_path):
            print(f"Warning: Class folder not found (skipping): {class_folder_path}")
            continue
        distribution_data[cls] = {}
        class_total = 0
        for sub_cls in sub_class_es:
            sub_class_folder_path = os.path.join(class_folder_path, sub_cls)
            if not os.path.isdir(sub_class_folder_path):
                print(f"Warning: Sub-class folder not found (skipping): {sub_class_folder_path}")
                distribution_data[cls][sub_cls] = 0
                continue
            image_count = 0
            for filename in os.listdir(sub_class_folder_path):
                if os.path.isfile(os.path.join(sub_class_folder_path, filename)) and filename.lower().endswith(('.png', '.jpg', '.jpeg')):
                    image_count += 1
            distribution_data[cls][sub_cls] = image_count
            class_total += image_count
        distribution_data[cls]['Total'] = class_total
        total_images += class_total
    df_distribution = pd.DataFrame(distribution_data)
    df_distribution['Sub-class Total'] = df_distribution.loc[sub_class_es].sum(axis=1)
    print("\nImage Distribution per Sub-class and Class:")
    display(df_distribution)
    print(f"\nTotal number of images found: {total_images}")

# %%
check_class_distribution(address, class_es, sub_class_es)
# Out:
# Checking class distribution in base directory: /content/drive/My Drive/PROJECT1/data/data_set(15,15,70)
#
# Image Distribution per Sub-class and Class:
#           test  train  valid  Sub-class Total
# Immature   281   1317    185           1783.0
# Mature     320   1499    321           2140.0
# Normal     324   1510    332           2166.0
# Total      925   4326    838              NaN
# Total number of images found: 6089
